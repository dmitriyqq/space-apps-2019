# %%
import pandas as pd

# %%
data = pd.read_csv('cities_data.csv')

# %%
df.head()
# Out:
#    id1         city   city_ascii      lat      lng country iso2 iso3  \
# 0    0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS
# 1    1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS
# 2    2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS
# 3    3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS
# 4    4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS
#
#     admin_name capital  population          id  elevation
# 0    Malishevë   admin         NaN  1901597212        529
# 1      Prizren   admin         NaN  1901360309        414
# 2  Zubin Potok   admin         NaN  1901608808        580
# 3     Kamenicë   admin         NaN  1901851592        476
# 4         Viti   admin         NaN  1901328795        500

# %%
data = df[df['population'] > 10000000]

# %%
data
# Out:
#          id1            city      city_ascii      lat       lng  \
# 1075    1075     Mexico City     Mexico City  19.4424  -99.1310
# 1685    1685          Manila          Manila  14.6042  120.9822
# 1790    1790         Karachi         Karachi  24.8700   66.9900
# 2220    2220          Moscow          Moscow  55.7522   37.6155
# 3412    3412        Istanbul        Istanbul  41.1050   29.0100
# 4240    4240    Buenos Aires    Buenos Aires -34.6025  -58.3975
# 4552    4552           Dhaka           Dhaka  23.7231   90.4086
# 5057    5057  Rio de Janeiro  Rio de Janeiro -22.9250  -43.2250
# 5105    5105       São Paulo       Sao Paulo -23.5587  -46.6250
# 5758    5758        Shanghai        Shanghai  31.2165  121.4365
# 5970    5970         Beijing         Beijing  39.9289  116.3883
# 6560    6560           Cairo           Cairo  30.0500   31.2500
# 7491    7491          Mumbai          Mumbai  19.0170   72.8570
# 7518    7518         Kolkata         Kolkata  22.4950   88.3247
# 7562    7562           Delhi           Delhi  28.6700   77.2300
# 7862    7862           Tokyo           Tokyo  35.6850  139.7514
# 7899    7899           Ōsaka           Osaka  34.7500  135.4601
# 9792    9792        New York        New York  40.6943  -73.9249
# 10465  10465     Los Angeles     Los Angeles  34.1139 -118.4068
#
#              country iso2 iso3                        admin_name  capital  \
# 1075          Mexico   MX  MEX                  Ciudad de México  primary
# 1685     Philippines   PH  PHL                               NaN  primary
# 1790        Pakistan   PK  PAK                             Sindh    admin
# 2220          Russia   RU  RUS                            Moskva  primary
# 3412          Turkey   TR  TUR                          İstanbul    admin
# 4240       Argentina   AR  ARG  Buenos Aires, Ciudad Autónoma de  primary
# 4552      Bangladesh   BD  BGD                             Dhaka  primary
# 5057          Brazil   BR  BRA                    Rio de Janeiro    admin
# 5105          Brazil   BR  BRA                         São Paulo    admin
# 5758           China   CN  CHN                          Shanghai    admin
# 5970           China   CN  CHN                           Beijing  primary
# 6560           Egypt   EG  EGY                        Al Qāhirah  primary
# 7491           India   IN  IND                       Mahārāshtra    admin
# 7518           India   IN  IND                       West Bengal    admin
# 7562           India   IN  IND                             Delhi    admin
# 7862           Japan   JP  JPN                             Tōkyō  primary
# 7899           Japan   JP  JPN                             Ōsaka    admin
# 9792   United States   US  USA                          New York      NaN
# 10465  United States   US  USA                        California      NaN
#
#        population          id  elevation
# 1075   19028000.0  1484247881       2238
# 1685   11100000.0  1608618140         13
# 1790   12130000.0  1586129469         11
# 2220   10452000.0  1643318494        144
# 3412   10061000.0  1792756324         94
# 4240   12795000.0  1032717330         37
# 4552   12797394.0  1050529279         17
# 5057   11748000.0  1076887657         25
# 5105   18845000.0  1076532519        730
# 5758   14987000.0  1156073548         17
# 5970   11106000.0  1156228865         51
# 6560   11893000.0  1818253931         28
# 7491   18978000.0  1356226629         11
# 7518   14787000.0  1356060520         12
# 7562   15926000.0  1356872604        212
# 7862   35676000.0  1392685764         27
# 7899   11294000.0  1392419823          4
# 9792   19354922.0  1840034016         17
# 10465  12815475.0  1840020491        338

# %%
import requests

# %%
elevations = []
for city in range(0, len(data), 250):
    
    points=[]
    
    for i in range(city, city+250 if city+250 < len(data) else len(data)):
        lat = data.iloc[i]['lat']
        lng = data.iloc[i]['lng']

        points.append((lat, lng))
        
    URL = "https://elevation-api.io/api/elevation?key=5S4gd0k0a3rccH-e0cakJdfinSuOt7"
    #PARAMS = {'latitude':lat, 'longitude': lng, 'application_max_assets_mtime': 1559625591}
    #print(points)
    r = requests.post(url = URL, json = {"points": points}) 

    if city % 1000 == 0:
        print(city)
        print(city / len(data) * 100, '%', sep='')

    # print(r)
    resp = r.json() 
    #print(resp)
    elevationsR = resp['elevations']
    for elevation in elevationsR:
        #print(elevation)
        elevations.append(elevation['elevation'])
        
    #if not resp['success']:
    #print('SURPRISE!')
data['elevation'] = elevations
# Out:
# 0
# 0.0%
# 1000
# 2.092050209205021%
# 2000
# 4.184100418410042%
# 3000
# 6.2761506276150625%
# 4000
# 8.368200836820083%
# 5000
# 10.460251046025103%
# 6000
# 12.552301255230125%
# 7000
# 14.644351464435147%
# 8000
# 16.736401673640167%
# 9000
# 18.828451882845187%
# 10000
# 20.920502092050206%
# 11000
# 23.01255230125523%
# 12000
# 25.10460251046025%
# 13000
# 27.19665271966527%
# 14000
# 29.288702928870293%
# 15000
# 31.380753138075313%
# 16000
# 33.47280334728033%
# 17000
# 35.56485355648535%
# 18000
# 37.65690376569037%
# 19000
# 39.74895397489539%
# 20000
# 41.84100418410041%
# 21000
# 43.93305439330544%
# 22000
# 46.02510460251046%
# 23000
# 48.11715481171548%
# 24000
# 50.2092050209205%
# 25000
# 52.30125523012552%
# 26000
# 54.39330543933054%
# 27000
# 56.48535564853556%
# 28000
# 58.57740585774059%
# 29000
# 60.66945606694561%
# 30000
# 62.76150627615063%
# 31000
# 64.85355648535564%
# 32000
# 66.94560669456067%
# 33000
# 69.0376569037657%
# 34000
# 71.1297071129707%
# 35000
# 73.22175732217573%
# 36000
# 75.31380753138075%
# 37000
# 77.40585774058577%
# 38000
# 79.49790794979079%
# 39000
# 81.58995815899581%
# 40000
# 83.68200836820083%
# 41000
# 85.77405857740585%
# 42000
# 87.86610878661088%
# 43000
# 89.9581589958159%
# 44000
# 92.05020920502092%
# 45000
# 94.14225941422593%
# 46000
# 96.23430962343096%
# 47000
# 98.32635983263597%
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(elevations)
# Out:
# 47800

# %%
data.to_csv('cities3.csv', index=False)

# %%
# data['iso3_len'] = data['iso3'].apply(len)

# %%
data['iso3_len'].value_counts()
# Out:
# 3    12959
# Name: iso3_len, dtype: int64

# %%
import psycopg2
import math

# %%
 conn = psycopg2.connect(dbname='postgres',user='postgres',host='localhost',password='mysecretpassword')

# %%
cur = conn.cursor()

# %%
len(data)
# Out:
# 12959

# %%
for c in range(0, len(data)):
    city, country, lat, lng, elevation, population, iso = data.iloc[c][['city', 'country', 'lat', 'lng', 'elevation', 'population', 'iso']]
    
    if c % 100 == 0:
        print(c)
        print(c / len(data) * 100, '%', sep='')

    if math.isnan(population):
        population = 0
    cur = conn.cursor()
    #print(city, country, float(lat), float(lng), int(elevation), int(population), iso3)
    r = cur.execute("rollback; INSERT INTO public.cities (name, country, pos, population, elevation, iso3) VALUES (%s, %s, 'SRID=4326;POINT(%s %s)', %s, %s, %s)", (city, country, float(lng), float(lat), int(population), int(elevation), iso))
    cur.close()
# Out:
# 0
# 0.0%
# 100
# 0.7716644802839725%
# 200
# 1.543328960567945%
# 300
# 2.314993440851918%
# 400
# 3.08665792113589%
# 500
# 3.858322401419863%
# 600
# 4.629986881703836%
# 700
# 5.401651361987807%
# 800
# 6.17331584227178%
# 900
# 6.944980322555752%
# 1000
# 7.716644802839726%
# 1100
# 8.488309283123698%
# 1200
# 9.259973763407672%
# 1300
# 10.031638243691642%
# 1400
# 10.803302723975614%
# 1500
# 11.574967204259588%
# 1600
# 12.34663168454356%
# 1700
# 13.118296164827534%
# 1800
# 13.889960645111504%
# 1900
# 14.661625125395478%
# 2000
# 15.433289605679452%
# 2100
# 16.204954085963426%
# 2200
# 16.976618566247396%
# 2300
# 17.74828304653137%
# 2400
# 18.519947526815344%
# 2500
# 19.291612007099314%
# 2600
# 20.063276487383284%
# 2700
# 20.834940967667258%
# 2800
# 21.606605447951228%
# 2900
# 22.378269928235202%
# 3000
# 23.149934408519176%
# 3100
# 23.921598888803146%
# 3200
# 24.69326336908712%
# 3300
# 25.464927849371094%
# 3400
# 26.236592329655068%
# 3500
# 27.00825680993904%
# 3600
# 27.779921290223008%
# 3700
# 28.551585770506982%
# 3800
# 29.323250250790956%
# 3900
# 30.09491473107493%
# 4000
# 30.866579211358903%
# 4100
# 31.638243691642877%
# 4200
# 32.40990817192685%
# 4300
# 33.18157265221082%
# 4400
# 33.95323713249479%
# 4500
# 34.724901612778766%
# 4600
# 35.49656609306274%
# 4700
# 36.26823057334671%
# 4800
# 37.03989505363069%
# 4900
# 37.811559533914654%
# 5000
# 38.58322401419863%
# 5100
# 39.3548884944826%
# 5200
# 40.12655297476657%
# 5300
# 40.89821745505054%
# 5400
# 41.669881935334516%
# 5500
# 42.44154641561849%
# 5600
# 43.213210895902456%
# 5700
# 43.98487537618643%
# 5800
# 44.756539856470404%
# 5900
# 45.52820433675438%
# 6000
# 46.29986881703835%
# 6100
# 47.071533297322325%
# 6200
# 47.84319777760629%
# 6300
# 48.614862257890266%
# 6400
# 49.38652673817424%
# 6500
# 50.158191218458214%
# 6600
# 50.92985569874219%
# 6700
# 51.70152017902616%
# 6800
# 52.473184659310135%
# 6900
# 53.24484913959411%
# 7000
# 54.01651361987808%
# 7100
# 54.78817810016206%
# 7200
# 55.559842580446016%
# 7300
# 56.33150706072999%
# 7400
# 57.103171541013964%
# 7500
# 57.87483602129794%
# 7600
# 58.64650050158191%
# 7700
# 59.418164981865885%
# 7800
# 60.18982946214986%
# 7900
# 60.96149394243383%
# 8000
# 61.73315842271781%
# 8100
# 62.50482290300178%
# 8200
# 63.276487383285755%
# 8300
# 64.04815186356973%
# 8400
# 64.8198163438537%
# 8500
# 65.59148082413766%
# 8600
# 66.36314530442164%
# 8700
# 67.13480978470561%
# 8800
# 67.90647426498958%
# 8900
# 68.67813874527356%
# 9000
# 69.44980322555753%
# 9100
# 70.2214677058415%
# 9200
# 70.99313218612548%
# 9300
# 71.76479666640945%
# 9400
# 72.53646114669343%
# 9500
# 73.3081256269774%
# 9600
# 74.07979010726137%
# 9700
# 74.85145458754533%
# 9800
# 75.62311906782931%
# 9900
# 76.39478354811328%
# 10000
# 77.16644802839726%
# 10100
# 77.93811250868123%
# 10200
# 78.7097769889652%
# 10300
# 79.48144146924918%
# 10400
# 80.25310594953314%
# 10500
# 81.02477042981711%
# 10600
# 81.79643491010108%
# 10700
# 82.56809939038506%
# 10800
# 83.33976387066903%
# 10900
# 84.111428350953%
# 11000
# 84.88309283123698%
# 11100
# 85.65475731152094%
# 11200
# 86.42642179180491%
# 11300
# 87.19808627208889%
# 11400
# 87.96975075237286%
# 11500
# 88.74141523265683%
# 11600
# 89.51307971294081%
# 11700
# 90.28474419322478%
# 11800
# 91.05640867350876%
# 11900
# 91.82807315379273%
# 12000
# 92.5997376340767%
# 12100
# 93.37140211436068%
# 12200
# 94.14306659464465%
# 12300
# 94.91473107492861%
# 12400
# 95.68639555521258%
# 12500
# 96.45806003549656%
# 12600
# 97.22972451578053%
# 12700
# 98.0013889960645%
# 12800
# 98.77305347634848%
# 12900
# 99.54471795663245%

# %%
cur = conn.cursor()
cur.execute("SELECT id, name, country, elevation, population, iso3, ST_X(C.pos::geometry) as lng, ST_Y(C.pos::geometry) as lat FROM public.cities C")
df = cur.fetchall()
cur.close()

# %%
swlat = 18.22935133838668
swlng =  -52.55859375000001
nelat = 70.8446726342528
nelng = 52.29492187500001

cur = conn.cursor()
cur.execute("SELECT * FROM cities C WHERE ST_Contains(ST_GEOMFROMTEXT('SRID=4326;POLYGON((%s %s, %s %s, %s %s, %s %s, %s %s))'), C.pos::geometry)", (swlng, swlat, swlng, nelat, nelng, nelat, nelng, swlat, swlng, swlat));
df = cur.fetchall()
cur.close()

# %%
df
# Out:
# [(1,
#   'Malishevë',
#   'Kosovo',
#   '0101000020E6100000575BB1BFECBE3440CB10C7BAB83D4540',
#   0,
#   529,
#   'NaN'),
#  (2,
#   'Prizren',
#   'Kosovo',
#   '0101000020E6100000E8D9ACFA5CBD3440A54E4013611B4540',
#   0,
#   414,
#   'NaN'),
#  (3,
#   'Zubin Potok',
#   'Kosovo',
#   '0101000020E61000001B0DE02D90B0344030BB270F0B754540',
#   0,
#   580,
#   'NaN'),
#  (4,
#   'Kamenicë',
#   'Kosovo',
#   '0101000020E61000006ADE718A8E943540A7E8482EFF494540',
#   0,
#   476,
#   'NaN'),
#  (5,
#   'Viti',
#   'Kosovo',
#   '0101000020E610000024287E8CB95B35409A779CA223294540',
#   0,
#   500,
#   'NaN'),
#  (6,
#   'Shtërpcë',
#   'Kosovo',
#   '0101000020E610000082734694F6063540CA54C1A8A41E4540',
#   0,
#   853,
#   'NaN'),
#  (7,
#   'Shtime',
#   'Kosovo',
#   '0101000020E6100000B5A679C7290A3540E5F21FD26F374540',
#   0,
#   572,
#   'NaN'),
#  (8,
#   'Vushtrri',
#   'Kosovo',
#   '0101000020E610000048E17A14AEF7344036AB3E575B694540',
#   0,
#   528,
#   'NaN'),
#  (9,
#   'Dragash',
#   'Kosovo',
#   '0101000020E6100000107A36AB3EA7344008AC1C5A64034540',
#   0,
#   1049,
#   'NaN'),
#  (10,
#   'Podujevë',
#   'Kosovo',
#   '0101000020E6100000AA8251499D3035405BB1BFEC9E744540',
#   0,
#   615,
#   'NaN'),
#  (11,
#   'Fushë Kosovë',
#   'Kosovo',
#   '0101000020E6100000462575029A1835403EE8D9ACFA544540',
#   0,
#   560,
#   'NaN'),
#  (12,
#   'Kaçanik',
#   'Kosovo',
#   '0101000020E61000001895D40968423540A1F831E6AE1D4540',
#   0,
#   485,
#   'NaN'),
#  (13,
#   'Klinë',
#   'Kosovo',
#   '0101000020E6100000F9A067B3EA9334402BF697DD934F4540',
#   0,
#   404,
#   'NaN'),
#  (14,
#   'Leposaviq',
#   'Kosovo',
#   '0101000020E6100000933A014D84CD3440F7065F984C8D4540',
#   0,
#   474,
#   'NaN'),
#  (15,
#   'Pejë',
#   'Kosovo',
#   '0101000020E610000026E4839ECD4A344014AE47E17A544540',
#   0,
#   514,
#   'NaN'),
#  (16,
#   'Rahovec',
#   'Kosovo',
#   '0101000020E6100000F2B0506B9AA73440DE02098A1F334540',
#   0,
#   392,
#   'NaN'),
#  (17,
#   'Gjilan',
#   'Kosovo',
#   '0101000020E61000009F3C2CD49A763540158C4AEA043C4540',
#   0,
#   517,
#   'NaN'),
#  (18,
#   'Lipjan',
#   'Kosovo',
#   '0101000020E610000039D6C56D342035405F29CB10C7424540',
#   0,
#   553,
#   'NaN'),
#  (19,
#   'Obiliq',
#   'Kosovo',
#   '0101000020E6100000A7E8482EFF113540ABCFD556EC574540',
#   0,
#   537,
#   'NaN'),
#  (20,
#   'Gjakovë',
#   'Kosovo',
#   '0101000020E6100000E71DA7E8486E34409B559FABAD304540',
#   0,
#   362,
#   'NaN'),
#  (21,
#   'Pristina',
#   'Kosovo',
#   '0101000020E610000095D40968222C3540BEC1172653554540',
#   0,
#   614,
#   'NaN'),
#  (22,
#   'Deçan',
#   'Kosovo',
#   '0101000020E610000098DD9387854A3440F7E461A1D6444540',
#   0,
#   604,
#   'NaN'),
#  (23,
#   'Istog',
#   'Kosovo',
#   '0101000020E6100000CDCCCCCCCC7C3440C05B2041F1634540',
#   0,
#   464,
#   'NaN'),
#  (24,
#   'Hani i Elezit',
#   'Kosovo',
#   '0101000020E610000024B9FC87F44B35403333333333134540',
#   0,
#   371,
#   'NaN'),
#  (25,
#   'Junik',
#   'Kosovo',
#   '0101000020E610000082734694F6463440E9B7AF03E73C4540',
#   0,
#   553,
#   'NaN'),
#  (26,
#   'Kllokot',
#   'Kosovo',
#   '0101000020E6100000569FABADD85F354001DE02098A2F4540',
#   0,
#   490,
#   'NaN'),
#  (27,
#   'Mamushë',
#   'Kosovo',
#   '0101000020E610000060764F1E16BA344027C286A7572A4540',
#   0,
#   332,
#   'NaN'),
#  (28,
#   'Partesh',
#   'Kosovo',
#   '0101000020E6100000AC8BDB68006F354096218E7571334540',
#   0,
#   491,
#   'NaN'),
#  (29,
#   'Ranillug',
#   'Kosovo',
#   '0101000020E61000000C93A98251993540AC8BDB68003F4540',
#   0,
#   444,
#   'NaN'),
#  (30,
#   'Ferizaj',
#   'Kosovo',
#   '0101000020E61000009D11A5BDC1273540E5F21FD26F2F4540',
#   0,
#   581,
#   'NaN'),
#  (31,
#   'Zveçan',
#   'Kosovo',
#   '0101000020E61000002CD49AE61DD734405C8FC2F528744540',
#   0,
#   546,
#   'NaN'),
#  (32,
#   'Suharekë',
#   'Kosovo',
#   '0101000020E61000003333333333D334403D2CD49AE62D4540',
#   0,
#   388,
#   'NaN'),
#  (33,
#   'Gllogovc',
#   'Kosovo',
#   '0101000020E6100000F7E461A1D6E43440D50968226C504540',
#   0,
#   584,
#   'NaN'),
#  (34,
#   'Mitrovicë',
#   'Kosovo',
#   '0101000020E610000076711B0DE0DD3440454772F90F714540',
#   0,
#   508,
#   'NaN'),
#  (35,
#   'Skenderaj',
#   'Kosovo',
#   '0101000020E610000027A089B0E1C934402BF697DD935F4540',
#   0,
#   611,
#   'NaN'),
#  (36,
#   'Novobërdë',
#   'Kosovo',
#   '0101000020E610000096218E75716B354002BC0512144F4540',
#   0,
#   1048,
#   'NaN'),
#  (37,
#   'Graçanicë',
#   'Kosovo',
#   '0101000020E61000008A8EE4F21F32354014D044D8F04C4540',
#   0,
#   588,
#   'NaN'),
#  (39,
#   'Al Quds',
#   'West Bank',
#   '0101000020E610000030BB270F0B9D4140499D8026C2C63F40',
#   0,
#   766,
#   'NaN'),
#  (199,
#   'Oral',
#   'Kazakhstan',
#   '0101000020E61000007B14AE47E1AA494009F9A067B3A24940',
#   209788,
#   32,
#   'NaN'),
#  (205,
#   'Chapaev',
#   'Kazakhstan',
#   '0101000020E61000005F984C158C9249408D976E1283184940',
#   6000,
#   14,
#   'NaN'),
#  (213,
#   'Makhambet',
#   'Kazakhstan',
#   '0101000020E6100000431CEBE236CA49406744696FF0D54740',
#   8905,
#   -21,
#   'NaN'),
#  (214,
#   'Fort Shevchenko',
#   'Kazakhstan',
#   '0101000020E61000008A8EE4F21F2249407C61325530424640',
#   5213,
#   16,
#   'NaN'),
#  (222,
#   'Zhanibek',
#   'Kazakhstan',
#   '0101000020E61000008E06F0164870474082E2C798BBB64840',
#   8212,
#   27,
#   'NaN'),
#  (233,
#   'Mangyshlak',
#   'Kazakhstan',
#   '0101000020E6100000EEEBC03923924940AAF1D24D62D84540',
#   147443,
#   4,
#   'NaN'),
#  (257,
#   'Aqtau',
#   'Kazakhstan',
#   '0101000020E610000083C0CAA1459E4940006F8104C5CF4540',
#   4479,
#   -27,
#   'NaN'),
#  (288,
#   'Balyqshy',
#   'Kazakhstan',
#   '0101000020E6100000575BB1BFECEE4940F1F44A5986884740',
#   31624,
#   -27,
#   'NaN'),
#  (289,
#   'Atyrau',
#   'Kazakhstan',
#   '0101000020E6100000F6285C8FC2F549402D211FF46C8E4740',
#   182753,
#   -30,
#   'NaN'),
#  (311,
#   'Beirut',
#   'Lebanon',
#   '0101000020E6100000B7627FD93DC14140560E2DB29DEF4040',
#   1846000,
#   49,
#   'NaN'),
#  (312,
#   'Zahlé',
#   'Lebanon',
#   '0101000020E610000088855AD3BCF34140302AA913D0EC4040',
#   78145,
#   1045,
#   'NaN'),
#  (313,
#   'Baalbek',
#   'Lebanon',
#   '0101000020E6100000F9A067B3EA1B42408D28ED0DBE004140',
#   0,
#   1182,
#   'NaN'),
#  (314,
#   "B'abda",
#   'Lebanon',
#   '0101000020E6100000787AA52C43C44140DFE00B93A9EA4040',
#   9000,
#   122,
#   'NaN'),
#  (315,
#   'Halba',
#   'Lebanon',
#   '0101000020E6100000E0BE0E9C330A424068226C787A454140',
#   0,
#   147,
#   'NaN'),
#  (316,
#   'Saida',
#   'Lebanon',
#   '0101000020E6100000E561A1D634AF4140F2D24D6210C84040',
#   173894,
#   13,
#   'NaN'),
#  (317,
#   'Nabatiye et Tahta',
#   'Lebanon',
#   '0101000020E61000009A99999999B94140454772F90FB14040',
#   80000,
#   411,
#   'NaN'),
#  (318,
#   'Trablous',
#   'Lebanon',
#   '0101000020E61000008FC2F5285CEF4140F6285C8FC2354140',
#   530000,
#   92,
#   'NaN'),
#  (320,
#   'Gamprin',
#   'Liechtenstein',
#   '0101000020E6100000BDE3141DC905234032772D211F9C4740',
#   0,
#   487,
#   'NaN'),
#  (321,
#   'Triesenberg',
#   'Liechtenstein',
#   '0101000020E610000082E2C798BB1623409031772D218F4740',
#   0,
#   896,
#   'NaN'),
#  (322,
#   'Schaan',
#   'Liechtenstein',
#   '0101000020E61000004D158C4AEA042340CCEEC9C342954740',
#   0,
#   454,
#   'NaN'),
#  (323,
#   'Ruggell',
#   'Liechtenstein',
#   '0101000020E6100000226C787AA50C23403B70CE88D29E4740',
#   0,
#   433,
#   'NaN'),
#  (324,
#   'Mauren',
#   'Liechtenstein',
#   '0101000020E6100000849ECDAACF1523404E621058399C4740',
#   0,
#   460,
#   'NaN'),
#  (325,
#   'Eschen',
#   'Liechtenstein',
#   '0101000020E6100000EC2FBB270F0B2340FB5C6DC5FE9A4740',
#   0,
#   447,
#   'NaN'),
#  (326,
#   'Triesen',
#   'Liechtenstein',
#   '0101000020E61000003F355EBA490C234012A5BDC1178E4740',
#   0,
#   465,
#   'NaN'),
#  (327,
#   'Balzers',
#   'Liechtenstein',
#   '0101000020E6100000E17A14AE47012340545227A089884740',
#   0,
#   477,
#   'NaN'),
#  (328,
#   'Vaduz',
#   'Liechtenstein',
#   '0101000020E6100000B8AF03E78C082340D3BCE3141D914740',
#   36281,
#   455,
#   'NaN'),
#  (329,
#   'Planken',
#   'Liechtenstein',
#   '0101000020E610000011363CBD52162340F2B0506B9A974740',
#   0,
#   782,
#   'NaN'),
#  (330,
#   'Schellenberg',
#   'Liechtenstein',
#   '0101000020E61000000F9C33A2B4172340F6285C8FC29D4740',
#   0,
#   633,
#   'NaN'),
#  (372,
#   'Klaipėda',
#   'Lithuania',
#   '0101000020E610000058CA32C4B11E3540EA04341136DC4B40',
#   192307,
#   10,
#   'NaN'),
#  (373,
#   'Palanga',
#   'Lithuania',
#   '0101000020E61000001804560E2D1235402041F163CCF54B40',
#   0,
#   7,
#   'NaN'),
#  (374,
#   'Nida',
#   'Lithuania',
#   '0101000020E6100000C976BE9F1AFF3440D6C56D3480A74B40',
#   0,
#   28,
#   'NaN'),
#  (375,
#   'Kretinga',
#   'Lithuania',
#   '0101000020E61000003BDF4F8D973E3540A857CA32C4F14B40',
#   0,
#   25,
#   'NaN'),
#  (376,
#   'Tauragė',
#   'Lithuania',
#   '0101000020E6100000B5A679C7294A36408E06F01648A04B40',
#   0,
#   35,
#   'NaN'),
#  (377,
#   'Šilutė',
#   'Lithuania',
#   '0101000020E6100000613255302A79354087A757CA32AC4B40',
#   0,
#   5,
#   'NaN'),
#  (378,
#   'Rietavas',
#   'Lithuania',
#   '0101000020E61000005C2041F163EC3540F775E09C11DD4B40',
#   0,
#   111,
#   'NaN'),
#  (379,
#   'Plungė',
#   'Lithuania',
#   '0101000020E6100000637FD93D79D83540234A7B832FF44B40',
#   0,
#   114,
#   'NaN'),
#  (380,
#   'Šilalė',
#   'Lithuania',
#   '0101000020E6100000569FABADD82F364058CA32C4B1BE4B40',
#   0,
#   98,
#   'NaN'),
#  (381,
#   'Visaginas',
#   'Lithuania',
#   '0101000020E6100000E3C798BB96703A405C2041F163CC4B40',
#   0,
#   157,
#   'NaN'),
#  (382,
#   'Zarasai',
#   'Lithuania',
#   '0101000020E610000055C1A8A44E403A40CB10C7BAB8DD4B40',
#   0,
#   152,
#   'NaN'),
#  (383,
#   'Ignalina',
#   'Lithuania',
#   '0101000020E61000000C022B8716293A404182E2C798AB4B40',
#   0,
#   165,
#   'NaN'),
#  (384,
#   'Utena',
#   'Lithuania',
#   '0101000020E610000061C3D32B65993940AB3E575BB1BF4B40',
#   0,
#   104,
#   'NaN'),
#  (385,
#   'Švenčionys',
#   'Lithuania',
#   '0101000020E610000046B6F3FDD4283A401B2FDD2406914B40',
#   0,
#   196,
#   'NaN'),
#  (386,
#   'Rokiškis',
#   'Lithuania',
#   '0101000020E610000063EE5A423E9839406D567DAEB6FA4B40',
#   0,
#   136,
#   'NaN'),
#  (387,
#   'Molėtai',
#   'Lithuania',
#   '0101000020E6100000D0B359F5B96A3940A2B437F8C29C4B40',
#   0,
#   161,
#   'NaN'),
#  (388,
#   'Šalčininkai',
#   'Lithuania',
#   '0101000020E6100000C217265305633940D6C56D3480274B40',
#   0,
#   175,
#   'NaN'),
#  (389,
#   'Vilnius',
#   'Lithuania',
#   '0101000020E6100000E2E995B20C5139400F0BB5A679574B40',
#   542366,
#   136,
#   'NaN'),
#  (390,
#   'Kupiškis',
#   'Lithuania',
#   '0101000020E6100000D044D8F0F4FA38404FAF946588EB4B40',
#   0,
#   96,
#   'NaN'),
#  (391,
#   'Trakai',
#   'Lithuania',
#   '0101000020E6100000560E2DB29DEF3840EE5A423EE8514B40',
#   0,
#   151,
#   'NaN'),
#  (392,
#   'Biržai',
#   'Lithuania',
#   '0101000020E6100000545227A089C03840287E8CB96B194C40',
#   0,
#   54,
#   'NaN'),
#  (393,
#   'Anykščiai',
#   'Lithuania',
#   '0101000020E6100000ECC039234A1B3940A5BDC11726C34B40',
#   0,
#   81,
#   'NaN'),
#  (394,
#   'Telšiai',
#   'Lithuania',
#   '0101000020E6100000EB73B515FB3B36404B598638D6FD4B40',
#   0,
#   131,
#   'NaN'),
#  (395,
#   'Kelmė',
#   'Lithuania',
#   '0101000020E6100000C8073D9B55EF3640D49AE61DA7D04B40',
#   0,
#   130,
#   'NaN'),
#  (396,
#   'Marijampolė',
#   'Lithuania',
#   '0101000020E61000007B832F4CA65A3740E4839ECDAA474B40',
#   0,
#   69,
#   'NaN'),
#  (397,
#   'Lazdijai',
#   'Lithuania',
#   '0101000020E61000004F401361C383374012143FC6DC1D4B40',
#   0,
#   125,
#   'NaN'),
#  (398,
#   'Šakiai',
#   'Lithuania',
#   '0101000020E6100000B1BFEC9E3C0C3740D200DE02097A4B40',
#   0,
#   51,
#   'NaN'),
#  (399,
#   'Radviliškis',
#   'Lithuania',
#   '0101000020E610000098DD9387858A37408FE4F21FD2E74B40',
#   0,
#   125,
#   'NaN'),
#  (400,
#   'Šiauliai',
#   'Lithuania',
#   '0101000020E610000033333333335337404703780B24F84B40',
#   133528,
#   106,
#   'NaN'),
#  (401,
#   'Birštonas',
#   'Lithuania',
#   '0101000020E6100000D5E76A2BF6073840764F1E166A4D4B40',
#   0,
#   50,
#   'NaN'),
#  (402,
#   'Druskininkai',
#   'Lithuania',
#   '0101000020E6100000E9263108ACFC37400B46257502024B40',
#   0,
#   98,
#   'NaN'),
#  (403,
#   'Kėdainiai',
#   'Lithuania',
#   '0101000020E6100000B7D100DE02F93740F7E461A1D6A44B40',
#   0,
#   39,
#   'NaN'),
#  (404,
#   'Alytus',
#   'Lithuania',
#   '0101000020E6100000ED0DBE30990A38403411363CBD324B40',
#   0,
#   90,
#   'NaN'),
#  (405,
#   'Prienai',
#   'Lithuania',
#   '0101000020E61000008A8EE4F21FF23740C520B07268514B40',
#   0,
#   60,
#   'NaN'),
#  (406,
#   'Elektrėnai',
#   'Lithuania',
#   '0101000020E610000061545227A0A93840226C787AA5644B40',
#   0,
#   111,
#   'NaN'),
#  (407,
#   'Kaunas',
#   'Lithuania',
#   '0101000020E6100000E17A14AE47E13740280F0BB5A6794B40',
#   374643,
#   83,
#   'NaN'),
#  (408,
#   'Jonava',
#   'Lithuania',
#   '0101000020E61000008351499D804638406E3480B7408A4B40',
#   0,
#   65,
#   'NaN'),
#  (409,
#   'Kaišiadorys',
#   'Lithuania',
#   '0101000020E6100000B9FC87F4DB773840499D8026C26E4B40',
#   0,
#   82,
#   'NaN'),
#  (410,
#   'Panevežys',
#   'Lithuania',
#   '0101000020E61000001F85EB51B85E38401F85EB51B8DE4B40',
#   127405,
#   52,
#   'NaN'),
#  (411,
#   'Joniškis',
#   'Lithuania',
#   '0101000020E61000005AF5B9DA8A9D3740CA54C1A8A41E4C40',
#   0,
#   49,
#   'NaN'),
#  (412,
#   'Kazlų Rūda',
#   'Lithuania',
#   '0101000020E61000001F85EB51B87E3740D5E76A2BF65F4B40',
#   0,
#   67,
#   'NaN'),
#  (413,
#   'Vilkaviškis',
#   'Lithuania',
#   '0101000020E61000002B8716D9CE0737406DE7FBA9F1524B40',
#   0,
#   55,
#   'NaN'),
#  (414,
#   'Pasvalys',
#   'Lithuania',
#   '0101000020E610000011363CBD526638400000000000084C40',
#   0,
#   31,
#   'NaN'),
#  (415,
#   'Pakruojis',
#   'Lithuania',
#   '0101000020E610000042CF66D5E7DA3740F7065F984CFD4B40',
#   0,
#   62,
#   'NaN'),
#  (416,
#   'Raseiniai',
#   'Lithuania',
#   '0101000020E610000072F90FE9B71F3740462575029AB04B40',
#   0,
#   93,
#   'NaN'),
#  (417,
#   'Pagėgiai',
#   'Lithuania',
#   '0101000020E6100000B515FBCBEEE93540280F0BB5A6914B40',
#   0,
#   14,
#   'NaN'),
#  (418,
#   'Jurbarkas',
#   'Lithuania',
#   '0101000020E61000006B9A779CA2C33640EFC9C342AD894B40',
#   0,
#   16,
#   'NaN'),
#  (419,
#   'Kalvarija',
#   'Lithuania',
#   '0101000020E610000043AD69DE713A374013F241CF66354B40',
#   0,
#   109,
#   'NaN'),
#  (420,
#   'Širvintos',
#   'Lithuania',
#   '0101000020E61000003108AC1C5AF438401283C0CAA1854B40',
#   0,
#   115,
#   'NaN'),
#  (421,
#   'Skuodas',
#   'Lithuania',
#   '0101000020E61000009C33A2B43788354018265305A3224C40',
#   0,
#   24,
#   'NaN'),
#  (422,
#   'Mažeikiai',
#   'Lithuania',
#   '0101000020E6100000DD24068195533640D5E76A2BF6274C40',
#   0,
#   71,
#   'NaN'),
#  (423,
#   'Akmenė',
#   'Lithuania',
#   '0101000020E61000000000000000C036400000000000204C40',
#   0,
#   74,
#   'NaN'),
#  (424,
#   'Ukmergė',
#   'Lithuania',
#   '0101000020E6100000C139234A7BC33840ABCFD556EC9F4B40',
#   0,
#   74,
#   'NaN'),
#  (425,
#   'Varėna',
#   'Lithuania',
#   '0101000020E61000004F1E166A4D933840DD240681951B4B40',
#   0,
#   129,
#   'NaN'),
#  (426,
#   'Capellen',
#   'Luxembourg',
#   '0101000020E6100000D881734694F61740C3F5285C8FD24840',
#   0,
#   316,
#   'NaN'),
#  (427,
#   'Esch-sur-Alzette',
#   'Luxembourg',
#   '0101000020E610000095D4096822EC1740ACADD85F76BF4840',
#   0,
#   296,
#   'NaN'),
#  (428,
#   'Remich',
#   'Luxembourg',
#   '0101000020E61000000F9C33A2B4771940F6285C8FC2C54840',
#   0,
#   157,
#   'NaN'),
#  (429,
#   'Echternach',
#   'Luxembourg',
#   '0101000020E61000001C7C613255B019402CD49AE61DE74840',
#   0,
#   236,
#   'NaN'),
#  (430,
#   'Mersch',
#   'Luxembourg',
#   '0101000020E6100000226C787AA56C1840B9FC87F4DBDF4840',
#   0,
#   218,
#   'NaN'),
#  (431,
#   'Redange-sur-Attert',
#   'Luxembourg',
#   '0101000020E6100000711B0DE02D901740A7E8482EFFE14840',
#   0,
#   289,
#   'NaN'),
#  (432,
#   'Vianden',
#   'Luxembourg',
#   '0101000020E6100000A089B0E1E9D5184048E17A14AEF74840',
#   0,
#   223,
#   'NaN'),
#  (433,
#   'Wiltz',
#   'Luxembourg',
#   '0101000020E6100000D1915CFE43BA1740158C4AEA04FC4840',
#   0,
#   320,
#   'NaN'),
#  (434,
#   'Clervaux',
#   'Luxembourg',
#   '0101000020E6100000AA60545227201840AC8BDB6800074940',
#   0,
#   361,
#   'NaN'),
#  (435,
#   'Diekirch',
#   'Luxembourg',
#   '0101000020E610000009F9A067B3AA1840454772F90FF14840',
#   6242,
#   324,
#   'NaN'),
#  (436,
#   'Grevenmacher',
#   'Luxembourg',
#   '0101000020E6100000F7065F984C5519409A99999999D94840',
#   3958,
#   313,
#   'NaN'),
#  (437,
#   'Luxembourg',
#   'Luxembourg',
#   '0101000020E610000085EB51B81E8518404A7B832F4CCE4840',
#   107260,
#   316,
#   'NaN'),
#  (438,
#   'Auce',
#   'Latvia',
#   '0101000020E61000002CD49AE61DE73640C2172653053B4C40',
#   0,
#   92,
#   'NaN'),
#  (439,
#   'Daugavpils',
#   'Latvia',
#   '0101000020E6100000C3F5285C8F823A40713D0AD7A3F04B40',
#   111564,
#   87,
#   'NaN'),
#  (440,
#   'Jēkabpils',
#   'Latvia',
#   '0101000020E61000009A99999999D9394012143FC6DC3D4C40',
#   0,
#   81,
#   'NaN'),
#  (441,
#   'Salacgrīva',
#   'Latvia',
#   '0101000020E610000096438B6CE75B38400E4FAF9465E04C40',
#   0,
#   7,
#   'NaN'),
#  (442,
#   'Ventspils',
#   'Latvia',
#   '0101000020E61000003A234A7B838F3540EE5A423EE8B14C40',
#   42884,
#   9,
#   'NaN'),
#  (443,
#   'Dundaga',
#   'Latvia',
#   '0101000020E6100000B6847CD0B3593640713D0AD7A3C04C40',
#   0,
#   63,
#   'NaN'),
#  (444,
#   'Jaunjelgava',
#   'Latvia',
#   '0101000020E6100000F7065F984C1539401FF46C567D4E4C40',
#   0,
#   46,
#   'NaN'),
#  (445,
#   'Nereta',
#   'Latvia',
#   '0101000020E6100000ADFA5C6DC54E3940B5A679C7291A4C40',
#   0,
#   81,
#   'NaN'),
#  (446,
#   'Alsunga',
#   'Latvia',
#   '0101000020E6100000AAF1D24D62903540A167B3EA737D4C40',
#   0,
#   25,
#   'NaN'),
#  (447,
#   'Kuldīga',
#   'Latvia',
#   '0101000020E61000002C8716D9CEF7354078E92631087C4C40',
#   0,
#   31,
#   'NaN'),
#  (448,
#   'Pāvilosta',
#   'Latvia',
#   '0101000020E6100000E6AE25E4832E35408BFD65F7E4714C40',
#   0,
#   6,
#   'NaN'),
#  (449,
#   'Piņķi',
#   'Latvia',
#   '0101000020E6100000EE5A423EE8E937401B0DE02D90784C40',
#   0,
#   7,
#   'NaN'),
#  (450,
#   'Ādaži',
#   'Latvia',
#   '0101000020E61000004A7B832F4C5638401B2FDD2406894C40',
#   0,
#   4,
#   'NaN'),
#  (451,
#   'Kandava',
#   'Latvia',
#   '0101000020E61000002F6EA301BCC536403EE8D9ACFA844C40',
#   0,
#   77,
#   'NaN'),
#  (452,
#   'Roja',
#   'Latvia',
#   '0101000020E61000003B014D840DCF3640D578E92631C04C40',
#   0,
#   14,
#   'NaN'),
#  (453,
#   'Carnikava',
#   'Latvia',
#   '0101000020E6100000F085C954C1483840B8AF03E78C904C40',
#   0,
#   2,
#   'NaN'),
#  (454,
#   'Garkalne',
#   'Latvia',
#   '0101000020E610000008AC1C5A646B384092CB7F48BF854C40',
#   0,
#   13,
#   'NaN'),
#  (455,
#   'Saulkrasti',
#   'Latvia',
#   '0101000020E61000005E4BC8073D6B38407E1D386744A14C40',
#   0,
#   8,
#   'NaN'),
#  (456,
#   'Smārde',
#   'Latvia',
#   '0101000020E6100000BB270F0BB55637406EA301BC057A4C40',
#   0,
#   20,
#   'NaN'),
#  (457,
#   'Mērsrags',
#   'Latvia',
#   '0101000020E6100000560E2DB29D1F3740EC2FBB270FAB4C40',
#   0,
#   7,
#   'NaN'),
#  (458,
#   'Talsi',
#   'Latvia',
#   '0101000020E61000002D211FF46C963640643BDF4F8D9F4C40',
#   0,
#   78,
#   'NaN'),
#  (459,
#   'Jūrmala',
#   'Latvia',
#   '0101000020E6100000613255302AB93740A60A4625757A4C40',
#   0,
#   9,
#   'NaN'),
#  (460,
#   'Mārupe',
#   'Latvia',
#   '0101000020E610000024B9FC87F40B3840A4DFBE0E9C734C40',
#   0,
#   11,
#   'NaN'),
#  (461,
#   'Ulbroka',
#   'Latvia',
#   '0101000020E61000002041F163CC4D3840569FABADD8774C40',
#   0,
#   17,
#   'NaN'),
#  (462,
#   'Zilupe',
#   'Latvia',
#   '0101000020E61000001EA7E8482E1F3C40C520B07268314C40',
#   0,
#   124,
#   'NaN'),
#  (463,
#   'Ludza',
#   'Latvia',
#   '0101000020E61000002B1895D409B83B40F775E09C11454C40',
#   0,
#   146,
#   'NaN'),
#  (464,
#   'Dagda',
#   'Latvia',
#   '0101000020E61000000E4FAF9465883B40A3923A014D0C4C40',
#   0,
#   183,
#   'NaN'),
#  (465,
#   'Baltinava',
#   'Latvia',
#   '0101000020E6100000BF9F1A2FDDA43B40E25817B7D1784C40',
#   0,
#   99,
#   'NaN'),
#  (466,
#   'Cibla',
#   'Latvia',
#   '0101000020E6100000A779C7293AE23B409FABADD85F464C40',
#   0,
#   117,
#   'NaN'),
#  (467,
#   'Kārsava',
#   'Latvia',
#   '0101000020E6100000CEAACFD556AC3B40696FF085C9644C40',
#   0,
#   106,
#   'NaN'),
#  (468,
#   'Riga',
#   'Latvia',
#   '0101000020E61000009A999999991938409A99999999794C40',
#   742572,
#   3,
#   'NaN'),
#  (469,
#   'Krāslava',
#   'Latvia',
#   '0101000020E610000078E92631082C3B4026E4839ECDF24B40',
#   0,
#   124,
#   'NaN'),
#  (470,
#   'Limbaži',
#   'Latvia',
#   '0101000020E6100000D34D621058B938408C6CE7FBA9C14C40',
#   0,
#   78,
#   'NaN'),
#  (471,
#   'Preiļi',
#   'Latvia',
#   '0101000020E61000000B24287E8CB93A401283C0CAA1254C40',
#   0,
#   126,
#   'NaN'),
#  (472,
#   'Vecvārkava',
#   'Latvia',
#   '0101000020E6100000FC1873D712823A4061C3D32B65194C40',
#   0,
#   97,
#   'NaN'),
#  (473,
#   'Ilūkste',
#   'Latvia',
#   '0101000020E6100000B1BFEC9E3C4C3A401361C3D32BFD4B40',
#   0,
#   97,
#   'NaN'),
#  (474,
#   'Nīca',
#   'Latvia',
#   '0101000020E6100000545227A089103540B1BFEC9E3C2C4C40',
#   0,
#   5,
#   'NaN'),
#  (475,
#   'Bauska',
#   'Latvia',
#   '0101000020E6100000A857CA32C4313840EA04341136344C40',
#   0,
#   31,
#   'NaN'),
#  (476,
#   'Viļaka',
#   'Latvia',
#   '0101000020E6100000B22E6EA301AC3B408F53742497974C40',
#   0,
#   95,
#   'NaN'),
#  (477,
#   'Līvāni',
#   'Latvia',
#   '0101000020E61000005BD3BCE3142D3A40D93D7958A82D4C40',
#   0,
#   88,
#   'NaN'),
#  (478,
#   'Alūksne',
#   'Latvia',
#   '0101000020E61000005DFE43FAED0B3B402EFF21FDF6B54C40',
#   0,
#   191,
#   'NaN'),
#  (479,
#   'Jaunpils',
#   'Latvia',
#   '0101000020E61000003333333333033740AF25E4839E5D4C40',
#   0,
#   68,
#   'NaN'),
#  (480,
#   'Brocēni',
#   'Latvia',
#   '0101000020E6100000A857CA32C491364090A0F831E6564C40',
#   0,
#   114,
#   'NaN'),
#  (481,
#   'Rugāji',
#   'Latvia',
#   '0101000020E6100000A779C7293A223B40D50968226C804C40',
#   0,
#   100,
#   'NaN'),
#  (482,
#   'Riebiņi',
#   'Latvia',
#   '0101000020E61000000612143FC6CC3A40166A4DF38E2B4C40',
#   0,
#   139,
#   'NaN'),
#  (483,
#   'Viļāni',
#   'Latvia',
#   '0101000020E610000020D26F5F07EE3A405839B4C876464C40',
#   0,
#   115,
#   'NaN'),
#  (484,
#   'Varakļāni',
#   'Latvia',
#   '0101000020E61000008C4AEA0434C13A402EFF21FDF64D4C40',
#   0,
#   100,
#   'NaN'),
#  (485,
#   'Ape',
#   'Latvia',
#   '0101000020E61000008C6CE7FBA9B13A4030BB270F0BC54C40',
#   0,
#   83,
#   'NaN'),
#  (486,
#   'Madona',
#   'Latvia',
#   '0101000020E61000004772F90FE9373A40B1726891ED6C4C40',
#   0,
#   137,
#   'NaN'),
#  (487,
#   'Jaunpiebalga',
#   'Latvia',
#   '0101000020E6100000D734EF3845073A401F85EB51B8964C40',
#   0,
#   163,
#   'NaN'),
#  (488,
#   'Lubāna',
#   'Latvia',
#   '0101000020E610000065AA605452B73A40EBE2361AC0734C40',
#   0,
#   93,
#   'NaN'),
#  (489,
#   'Gulbene',
#   'Latvia',
#   '0101000020E6100000FFB27BF2B0C03A402E90A0F831964C40',
#   0,
#   121,
#   'NaN'),
#  (490,
#   'Balvi',
#   'Latvia',
#   '0101000020E610000085EB51B81E453B40637FD93D79904C40',
#   0,
#   114,
#   'NaN'),
#  (491,
#   'Aknīste',
#   'Latvia',
#   '0101000020E610000001DE02098ABF3940E9263108AC144C40',
#   0,
#   90,
#   'NaN'),
#  (492,
#   'Viesīte',
#   'Latvia',
#   '0101000020E6100000C9E53FA4DF8E39403108AC1C5A2C4C40',
#   0,
#   111,
#   'NaN'),
#  (493,
#   'Cesvaine',
#   'Latvia',
#   '0101000020E6100000E63FA4DFBE4E3A40A4703D0AD77B4C40',
#   0,
#   165,
#   'NaN'),
#  (494,
#   'Ķegums',
#   'Latvia',
#   '0101000020E61000009A99999999B938408195438B6C5F4C40',
#   0,
#   46,
#   'NaN'),
#  (495,
#   'Vecpiebalga',
#   'Latvia',
#   '0101000020E6100000FE65F7E461D139404772F90FE9874C40',
#   0,
#   211,
#   'NaN'),
#  (496,
#   'Smiltene',
#   'Latvia',
#   '0101000020E61000009FCDAACFD5E639404A7B832F4CB64C40',
#   0,
#   98,
#   'NaN'),
#  (497,
#   'Drabeši',
#   'Latvia',
#   '0101000020E61000009D11A5BDC1473940F38E5374249F4C40',
#   0,
#   153,
#   'NaN'),
#  (498,
#   'Cēsis',
#   'Latvia',
#   '0101000020E6100000F46C567DAE463940C898BB9690A74C40',
#   0,
#   103,
#   'NaN'),
#  (499,
#   'Ērgļi',
#   'Latvia',
#   '0101000020E610000031992A1895A4394089D2DEE00B734C40',
#   0,
#   170,
#   'NaN'),
#  (500,
#   'Valka',
#   'Latvia',
#   '0101000020E6100000C217265305033A40CF66D5E76AE34C40',
#   0,
#   48,
#   'NaN'),
#  (501,
#   'Grobiņa',
#   'Latvia',
#   '0101000020E6100000789CA223B92C354031992A1895444C40',
#   0,
#   22,
#   'NaN'),
#  (502,
#   'Strenči',
#   'Latvia',
#   '0101000020E6100000371AC05B20B1394063EE5A423ED04C40',
#   0,
#   43,
#   'NaN'),
#  (503,
#   'Mūrmuiža',
#   'Latvia',
#   '0101000020E610000076711B0DE07D39406ADE718A8EBC4C40',
#   0,
#   63,
#   'NaN'),
#  (504,
#   'Mazsalaca',
#   'Latvia',
#   '0101000020E61000005917B7D1000E394011363CBD52EE4C40',
#   0,
#   58,
#   'NaN'),
#  (505,
#   'Aloja',
#   'Latvia',
#   '0101000020E6100000AA8251499DE03840E0BE0E9C33E24C40',
#   0,
#   85,
#   'NaN'),
#  (506,
#   'Burtnieki',
#   'Latvia',
#   '0101000020E61000006666666666463940C5FEB27BF2D84C40',
#   0,
#   48,
#   'NaN'),
#  (507,
#   'Koknese',
#   'Latvia',
#   '0101000020E610000072F90FE9B76F39406C09F9A067534C40',
#   0,
#   86,
#   'NaN'),
#  (508,
#   'Aizkraukle',
#   'Latvia',
#   '0101000020E6100000C139234A7B4339401361C3D32B4D4C40',
#   0,
#   87,
#   'NaN'),
#  (509,
#   'Skrīveri',
#   'Latvia',
#   '0101000020E61000003BDF4F8D971E39405EBA490C02534C40',
#   0,
#   74,
#   'NaN'),
#  (510,
#   'Baldone',
#   'Latvia',
#   '0101000020E61000009F3C2CD49A6638409EEFA7C64B5F4C40',
#   0,
#   30,
#   'NaN'),
#  (511,
#   'Vecumnieki',
#   'Latvia',
#   '0101000020E610000068B3EA73B5853840840D4FAF944D4C40',
#   0,
#   36,
#   'NaN'),
#  (512,
#   'Sala',
#   'Latvia',
#   '0101000020E6100000C217265305C33940462575029A404C40',
#   0,
#   86,
#   'NaN'),
#  (513,
#   'Pļaviņas',
#   'Latvia',
#   '0101000020E61000000EBE30992AB839409E5E29CB104F4C40',
#   0,
#   77,
#   'NaN'),
#  (514,
#   'Liepaga',
#   'Latvia',
#   '0101000020E6100000C3F5285C8F023540E17A14AE47414C40',
#   85132,
#   8,
#   'NaN'),
#  (515,
#   'Rūjiena',
#   'Latvia',
#   '0101000020E6100000BD5296218E55394009F9A067B3F24C40',
#   0,
#   56,
#   'NaN'),
#  (516,
#   'Naukšēni',
#   'Latvia',
#   '0101000020E61000006991ED7C3F753940C58F31772DF14C40',
#   0,
#   57,
#   'NaN'),
#  (517,
#   'Lieģi',
#   'Latvia',
#   '0101000020E6100000A167B3EA73553540E0BE0E9C334A4C40',
#   0,
#   47,
#   'NaN'),
#  (518,
#   'Rauna',
#   'Latvia',
#   '0101000020E6100000B29DEFA7C69B39406D567DAEB6AA4C40',
#   0,
#   106,
#   'NaN'),
#  (519,
#   'Aizpute',
#   'Latvia',
#   '0101000020E61000000B462575029A3540A3923A014D5C4C40',
#   0,
#   60,
#   'NaN'),
#  (520,
#   'Kocēni',
#   'Latvia',
#   '0101000020E6100000F38E537424573940FB3A70CE88C24C40',
#   0,
#   62,
#   'NaN'),
#  (521,
#   'Valmiera',
#   'Latvia',
#   '0101000020E61000003EE8D9ACFA6C3940772D211FF4C44C40',
#   0,
#   47,
#   'NaN'),
#  (522,
#   'Sigulda',
#   'Latvia',
#   '0101000020E610000079E9263108DC3840F90FE9B7AF934C40',
#   0,
#   99,
#   'NaN'),
#  (523,
#   'Priekuļi',
#   'Latvia',
#   '0101000020E6100000CF66D5E76A5B39401D5A643BDFA74C40',
#   0,
#   120,
#   'NaN'),
#  (524,
#   'Ogre',
#   'Latvia',
#   '0101000020E6100000780B24287E9C3840569FABADD8674C40',
#   0,
#   23,
#   'NaN'),
#  (525,
#   'Ragana',
#   'Latvia',
#   '0101000020E6100000BF0E9C33A2B43840014D840D4F974C40',
#   0,
#   49,
#   'NaN'),
#  (526,
#   'Loja',
#   'Latvia',
#   '0101000020E61000004D840D4FAFA438406B9A779CA2934C40',
#   0,
#   49,
#   'NaN'),
#  (527,
#   'Ropaži',
#   'Latvia',
#   '0101000020E61000006EA301BC05A23840A2B437F8C27C4C40',
#   0,
#   42,
#   'NaN'),
#  (528,
#   'Priekule',
#   'Latvia',
#   '0101000020E61000002B1895D409983540454772F90F394C40',
#   0,
#   60,
#   'NaN'),
#  (529,
#   'Iecava',
#   'Latvia',
#   '0101000020E61000004CA60A4625353840DC68006F814C4C40',
#   0,
#   23,
#   'NaN'),
#  (530,
#   'Rucava',
#   'Latvia',
#   '0101000020E6100000280F0BB5A6293540A145B6F3FD144C40',
#   0,
#   12,
#   'NaN'),
#  (531,
#   'Pilsrundāle',
#   'Latvia',
#   '0101000020E6100000F931E6AE25043840933A014D84354C40',
#   0,
#   21,
#   'NaN'),
#  (532,
#   'Salaspils',
#   'Latvia',
#   '0101000020E61000000B24287E8C59384092ED7C3F356E4C40',
#   0,
#   15,
#   'NaN'),
#  (533,
#   'Ikšķile',
#   'Latvia',
#   '0101000020E61000001EA7E8482E7F3840976E1283C06A4C40',
#   0,
#   33,
#   'NaN'),
#  (534,
#   'Lielvārde',
#   'Latvia',
#   '0101000020E610000003098A1F63CE38406A4DF38E535C4C40',
#   0,
#   48,
#   'NaN'),
#  (535,
#   'Inčukalns',
#   'Latvia',
#   '0101000020E6100000AB3E575BB1AF3840BF0E9C33A28C4C40',
#   0,
#   55,
#   'NaN'),
#  (536,
#   'Mālpils',
#   'Latvia',
#   '0101000020E6100000DA1B7C6132F5384045D8F0F44A814C40',
#   0,
#   99,
#   'NaN'),
#  (537,
#   'Olaine',
#   'Latvia',
#   '0101000020E6100000C898BB9690EF3740CB10C7BAB8654C40',
#   0,
#   9,
#   'NaN'),
#  (538,
#   'Ķekava',
#   'Latvia',
#   '0101000020E61000007A36AB3E573B38407C613255306A4C40',
#   0,
#   10,
#   'NaN'),
#  (539,
#   'Līgatne',
#   'Latvia',
#   '0101000020E6100000091B9E5E290B3940F5DBD781739E4C40',
#   0,
#   44,
#   'NaN'),
#  (540,
#   'Stalbe',
#   'Latvia',
#   '0101000020E6100000F163CC5D4B083940ACADD85F76AF4C40',
#   0,
#   65,
#   'NaN'),
#  (541,
#   'Jelgava',
#   'Latvia',
#   '0101000020E6100000BC96900F7AB63740B30C71AC8B534C40',
#   67207,
#   5,
#   'NaN'),
#  (542,
#   'Skrunda',
#   'Latvia',
#   '0101000020E61000004E621058390436401F85EB51B8564C40',
#   0,
#   36,
#   'NaN'),
#  (543,
#   'Vaiņode',
#   'Latvia',
#   '0101000020E61000007B832F4CA6DA354021B0726891354C40',
#   0,
#   148,
#   'NaN'),
#  (544,
#   'Saldus',
#   'Latvia',
#   '0101000020E610000075931804567E3640BEC1172653554C40',
#   0,
#   96,
#   'NaN'),
#  (545,
#   'Tukums',
#   'Latvia',
#   '0101000020E61000002B8716D9CE27374007CE1951DA7B4C40',
#   0,
#   62,
#   'NaN'),
#  (546,
#   'Tērvete',
#   'Latvia',
#   '0101000020E610000032E6AE25E4633740764F1E166A3D4C40',
#   0,
#   46,
#   'NaN'),
#  (547,
#   'Dobele',
#   'Latvia',
#   '0101000020E61000002D211FF46C463740F241CF66D54F4C40',
#   0,
#   39,
#   'NaN'),
#  (548,
#   'Rēzekne',
#   'Latvia',
#   '0101000020E6100000E2E995B20C513B400000000000404C40',
#   38340,
#   136,
#   'NaN'),
#  (549,
#   'Aglona',
#   'Latvia',
#   '0101000020E6100000E09C11A5BD013B40F0164850FC104C40',
#   0,
#   150,
#   'NaN'),
#  (550,
#   'Ozolnieki',
#   'Latvia',
#   '0101000020E6100000F46C567DAEC6374055C1A8A44E584C40',
#   0,
#   10,
#   'NaN'),
#  (551,
#   'Tripoli',
#   'Libya',
#   '0101000020E61000005C8FC2F5285C2A400AD7A3703D724040',
#   2189000,
#   6,
#   'NaN'),
#  (552,
#   'Al ‘Azīzīyah',
#   'Libya',
#   '0101000020E6100000295C8FC2F5082A40075F984C15444040',
#   0,
#   116,
#   'NaN'),
#  (553,
#   'Zuwarah',
#   'Libya',
#   '0101000020E61000002A3A92CB7F282840F2B0506B9A774040',
#   180310,
#   6,
#   'NaN'),
#  (554,
#   'Al Khums',
#   'Libya',
#   '0101000020E610000085EB51B81E852C40A323B9FC87544040',
#   201943,
#   0,
#   'NaN'),
#  (555,
#   'As Sidr',
#   'Libya',
#   '0101000020E6100000151DC9E53F443240083D9B559FAB3E40',
#   50,
#   16,
#   'NaN'),
#  (556,
#   'Ghadamis',
#   'Libya',
#   '0101000020E610000000000000000023408A8EE4F21F223E40',
#   6623,
#   338,
#   'NaN'),
#  (557,
#   'Dirj',
#   'Libya',
#   '0101000020E6100000992A1895D4E9244097FF907EFB2A3E40',
#   931,
#   420,
#   'NaN'),
#  (558,
#   'Nalut',
#   'Libya',
#   '0101000020E6100000713D0AD7A3F02540FE65F7E461E13F40',
#   66609,
#   639,
#   'NaN'),
#  (559,
#   'Umm al Abid',
#   'Libya',
#   '0101000020E6100000E2E995B20C112E403108AC1C5A843B40',
#   300,
#   396,
#   'NaN'),
#  (560,
#   'Sabha',
#   'Libya',
#   '0101000020E6100000AEB6627FD9DD2C40F1F44A5986083B40',
#   100249,
#   422,
#   'NaN'),
#  (561,
#   'Birak',
#   'Libya',
#   '0101000020E6100000705F07CE19912C40F1F44A5986883B40',
#   45421,
#   337,
#   'NaN'),
#  (562,
#   'Idrī',
#   'Libya',
#   '0101000020E61000000A68226C781A2A40A60A462575723B40',
#   0,
#   379,
#   'NaN'),
#  (563,
#   'Zillah',
#   'Libya',
#   '0101000020E6100000857CD0B359953140E9B7AF03E78C3C40',
#   10,
#   163,
#   'NaN'),
#  (564,
#   'Hun',
#   'Libya',
#   '0101000020E6100000AEB6627FD9DD2F4076711B0DE01D3D40',
#   18878,
#   263,
#   'NaN'),
#  (565,
#   'Az Zawiyah',
#   'Libya',
#   '0101000020E6100000713D0AD7A37029406FF085C954614040',
#   200000,
#   15,
#   'NaN'),
#  (566,
#   'Awjilah',
#   'Libya',
#   '0101000020E6100000EF38454772493540CFF753E3A51B3D40',
#   6610,
#   44,
#   'NaN'),
#  (567,
#   'El Agheila',
#   'Libya',
#   '0101000020E610000033333333333333406E1283C0CA413E40',
#   100,
#   10,
#   'NaN'),
#  (568,
#   'Maradah',
#   'Libya',
#   '0101000020E61000004850FC1873373340401361C3D33B3D40',
#   2500,
#   36,
#   'NaN'),
#  (569,
#   'Ajdabiya',
#   'Libya',
#   '0101000020E6100000B81E85EB5138344085EB51B81EC53E40',
#   143833,
#   5,
#   'NaN'),
#  (570,
#   'Darnah',
#   'Libya',
#   '0101000020E6100000A4DFBE0E9CA336408BFD65F7E4614040',
#   127974,
#   17,
#   'NaN'),
#  (571,
#   'Al Jaghbub',
#   'Libya',
#   '0101000020E6100000151DC9E53F8438401CEBE2361AC03D40',
#   1744,
#   1,
#   'NaN'),
#  (572,
#   'Mizdah',
#   'Libya',
#   '0101000020E61000004850FC1873F72940744694F6066F3F40',
#   26107,
#   456,
#   'NaN'),
#  (573,
#   'Gharyan',
#   'Libya',
#   '0101000020E61000000AD7A3703D0A2A40849ECDAACF154040',
#   146810,
#   696,
#   'NaN'),
#  (574,
#   'Tubruq',
#   'Libya',
#   '0101000020E6100000F6285C8FC2F537400AD7A3703D0A4040',
#   263527,
#   5,
#   'NaN'),
#  (575,
#   'Shahhat',
#   'Libya',
#   '0101000020E6100000789CA223B9DC3540A7E8482EFF694040',
#   45000,
#   547,
#   'NaN'),
#  (576,
#   'Tajarhi',
#   'Libya',
#   '0101000020E6100000E2E995B20CF12C403B70CE88D25E3840',
#   1500,
#   513,
#   'NaN'),
#  (577,
#   'Al Bayda',
#   'Libya',
#   '0101000020E61000001F85EB51B89E35406FF085C954614040',
#   1794,
#   488,
#   'NaN'),
#  (578,
#   'Ghat',
#   'Libya',
#   '0101000020E6100000637FD93D7958244082734694F6F63840',
#   24347,
#   678,
#   'NaN'),
#  (579,
#   'Tmassah',
#   'Libya',
#   '0101000020E61000009A99999999992F40AEB6627FD95D3A40',
#   500,
#   418,
#   'NaN'),
#  (580,
#   'Marzuq',
#   'Libya',
#   '0101000020E610000041F163CC5DCB2B409D8026C286E73940',
#   55071,
#   448,
#   'NaN'),
#  (581,
#   'Al Marj',
#   'Libya',
#   '0101000020E610000014AE47E17AD43440F2D24D6210404040',
#   169540,
#   334,
#   'NaN'),
#  (582,
#   'Surt',
#   'Libya',
#   '0101000020E6100000D7A3703D0A973040F6285C8FC2353F40',
#   128123,
#   19,
#   'NaN'),
#  (583,
#   'Bani Walid',
#   'Libya',
#   '0101000020E61000007B14AE47E1FA2B40A1D634EF38C53F40',
#   65392,
#   249,
#   'NaN'),
#  (584,
#   'Awbārī',
#   'Libya',
#   '0101000020E61000005B423EE8D98C29402CD49AE61D973A40',
#   0,
#   468,
#   'NaN'),
#  (585,
#   'Al Jawf',
#   'Libya',
#   '0101000020E61000000AD7A3703D4A37403333333333333840',
#   24132,
#   390,
#   'NaN'),
#  (586,
#   'Al Kufrah',
#   'Libya',
#   '0101000020E610000069006F8104453740423EE8D9AC2A3840',
#   0,
#   383,
#   'NaN'),
#  (587,
#   'Qaminis',
#   'Libya',
#   '0101000020E61000008716D9CEF7033440D3BCE3141DA93F40',
#   5348,
#   16,
#   'NaN'),
#  (588,
#   'Banghazi',
#   'Libya',
#   '0101000020E6100000A9A44E4013113440BBB88D06F00E4040',
#   1180000,
#   7,
#   'NaN'),
#  (589,
#   'Misratah',
#   'Libya',
#   '0101000020E61000003333333333332E40713D0AD7A3304040',
#   386120,
#   5,
#   'NaN'),
#  (590,
#   'Kenitra',
#   'Morocco',
#   '0101000020E610000052B81E85EB511AC0516B9A779C224140',
#   551786,
#   7,
#   'NaN'),
#  (591,
#   'Goulimine',
#   'Morocco',
#   '0101000020E6100000A4703D0AD72324C07B14AE47E1FA3C40',
#   115267,
#   271,
#   'NaN'),
#  (592,
#   'Fez',
#   'Morocco',
#   '0101000020E610000071AC8BDB680014C0492EFF21FD064140',
#   1002000,
#   378,
#   'NaN'),
#  (593,
#   'Casablanca',
#   'Morocco',
#   '0101000020E61000008104C58F31771EC0CDCCCCCCCCCC4040',
#   3181000,
#   12,
#   'NaN'),
#  (594,
#   'Agadir',
#   'Morocco',
#   '0101000020E61000003D0AD7A3703D23C0713D0AD7A3703E40',
#   825467,
#   116,
#   'NaN'),
#  (595,
#   'Béni Mellal',
#   'Morocco',
#   '0101000020E61000002E90A0F8316619C06C787AA52C2B4040',
#   0,
#   538,
#   'NaN'),
#  (596,
#   'Tangier',
#   'Morocco',
#   '0101000020E61000004D840D4FAF5417C08126C286A7DF4140',
#   750060,
#   87,
#   'NaN'),
#  (597,
#   'Settat',
#   'Morocco',
#   '0101000020E61000007B14AE47E17A1EC06FF085C954814040',
#   161748,
#   354,
#   'NaN'),
#  (598,
#   'Oujda',
#   'Morocco',
#   '0101000020E61000008FC2F5285C8FFEBFB81E85EB51584140',
#   409391,
#   549,
#   'NaN'),
#  (599,
#   'Meknes',
#   'Morocco',
#   '0101000020E61000003D0AD7A3703D16C0C1A8A44E40F34040',
#   697628,
#   497,
#   'NaN'),
#  (600,
#   'Rabat',
#   'Morocco',
#   '0101000020E61000000EBE30992A581BC05E4BC8073D034140',
#   1705000,
#   24,
#   'NaN'),
#  (601,
#   'Marrakesh',
#   'Morocco',
#   '0101000020E610000000000000000020C0E17A14AE47A13F40',
#   872000,
#   459,
#   'NaN'),
#  (602,
#   'El Jadida',
#   'Morocco',
#   '0101000020E610000085EB51B81E0521C06FF085C954A14040',
#   180470,
#   11,
#   'NaN'),
#  (603,
#   'Er Rachidia',
#   'Morocco',
#   '0101000020E6100000CDCCCCCCCCCC11C08D28ED0DBEF03F40',
#   228489,
#   1047,
#   'NaN'),
#  (604,
#   'Tan Tan',
#   'Morocco',
#   '0101000020E610000033333333333326C0CA32C4B12E6E3C40',
#   64868,
#   65,
#   'NaN'),
#  (605,
#   'Taza',
#   'Morocco',
#   '0101000020E610000014AE47E17A1410C0EA043411361C4140',
#   199633,
#   459,
#   'NaN'),
#  (606,
#   'Larache',
#   'Morocco',
#   '0101000020E6100000A4703D0AD7A318C0280F0BB5A6994140',
#   120082,
#   0,
#   'NaN'),
#  (607,
#   'Ksar El Kebir',
#   'Morocco',
#   '0101000020E6100000A4703D0AD7A317C0516B9A779C824140',
#   306600,
#   21,
#   'NaN'),
#  (608,
#   'Safi',
#   'Morocco',
#   '0101000020E61000007B14AE47E17A22C0295C8FC2F5284040',
#   353476,
#   104,
#   'NaN'),
#  (609,
#   'Tiznit',
#   'Morocco',
#   '0101000020E61000007B14AE47E17A23C012143FC6DCB53D40',
#   57705,
#   225,
#   'NaN'),
#  (610,
#   'Ouezzane',
#   'Morocco',
#   '0101000020E610000048E17A14AE4716C072F90FE9B7674140',
#   69658,
#   261,
#   'NaN'),
#  (611,
#   'Monaco',
#   'Monaco',
#   '0101000020E610000038F8C264AAA01D40910F7A36ABDE4540',
#   36371,
#   300,
#   'NaN'),
#  (612,
#   'Leova',
#   'Moldova',
#   '0101000020E610000054E3A59BC4403C402F6EA301BC3D4740',
#   0,
#   37,
#   'NaN'),
#  (613,
#   'Rezina',
#   'Moldova',
#   '0101000020E6100000107A36AB3EF73C404772F90FE9DF4740',
#   0,
#   137,
#   'NaN'),
#  (614,
#   'Căuşeni',
#   'Moldova',
#   '0101000020E6100000B7627FD93D693D407DAEB6627F514740',
#   0,
#   32,
#   'NaN'),
#  (615,
#   'Rîşcani',
#   'Moldova',
#   '0101000020E61000001C7C613255903B406FF085C954F94740',
#   0,
#   135,
#   'NaN'),
#  (616,
#   'Sîngerei',
#   'Moldova',
#   '0101000020E6100000F853E3A59B243C40EF38454772D14740',
#   0,
#   89,
#   'NaN'),
#  (617,
#   'Făleşti',
#   'Moldova',
#   '0101000020E61000002D211FF46CB63B4036CD3B4ED1C94740',
#   0,
#   120,
#   'NaN'),
#  (618,
#   'Floreşti',
#   'Moldova',
#   '0101000020E61000002575029A084B3C40C3D32B6519F24740',
#   0,
#   118,
#   'NaN'),
#  (619,
#   'Şoldăneşti',
#   'Moldova',
#   '0101000020E6100000075F984C15CC3C40FF21FDF675E84740',
#   0,
#   148,
#   'NaN'),
#  (620,
#   'Ştefan Vodă',
#   'Moldova',
#   '0101000020E6100000EF38454772A93D40280F0BB5A6414740',
#   0,
#   164,
#   'NaN'),
#  (621,
#   'Orhei',
#   'Moldova',
#   '0101000020E6100000508D976E12D33C407E1D386744B14740',
#   0,
#   84,
#   'NaN'),
#  (622,
#   'Comrat',
#   'Moldova',
#   '0101000020E6100000F2D24D6210A83C4068B3EA73B5254740',
#   0,
#   62,
#   'NaN'),
#  (623,
#   'Cimişlia',
#   'Moldova',
#   '0101000020E6100000F90FE9B7AFC33C4033C4B12E6E434740',
#   0,
#   116,
#   'NaN'),
#  (624,
#   'Cantemir',
#   'Moldova',
#   '0101000020E610000032E6AE25E4333C4088F4DBD781234740',
#   0,
#   55,
#   'NaN'),
#  (625,
#   'Basarabeasca',
#   'Moldova',
#   '0101000020E6100000F46C567DAEF63C40A60A4625752A4740',
#   0,
#   59,
#   'NaN'),
#  (626,
#   'Edineţ',
#   'Moldova',
#   '0101000020E61000003D9B559FAB4D3B4020D26F5F07164840',
#   0,
#   214,
#   'NaN'),
#  (627,
#   'Ocniţa',
#   'Moldova',
#   '0101000020E6100000AA60545227703B40F0164850FC304840',
#   0,
#   217,
#   'NaN'),
#  (628,
#   'Drochia',
#   'Moldova',
#   '0101000020E61000001CEBE2361AD03B40068195438B044840',
#   0,
#   218,
#   'NaN'),
#  (629,
#   'Donduşeni',
#   'Moldova',
#   '0101000020E61000002575029A089B3B40CA54C1A8A41E4840',
#   0,
#   237,
#   'NaN'),
#  (630,
#   'Briceni',
#   'Moldova',
#   '0101000020E6100000C05B2041F1133B40F5DBD781732E4840',
#   0,
#   235,
#   'NaN'),
#  (631,
#   'Ialoveni',
#   'Moldova',
#   '0101000020E61000002AA913D044C83C4054E3A59BC4784740',
#   0,
#   97,
#   'NaN'),
#  (632,
#   'Bălți',
#   'Moldova',
#   '0101000020E61000009D11A5BDC1E73B40613255302AE14740',
#   151355,
#   125,
#   'NaN'),
#  (633,
#   'Criuleni',
#   'Moldova',
#   '0101000020E6100000B84082E2C7283D4088635DDC469B4740',
#   0,
#   31,
#   'NaN'),
#  (634,
#   'Bender',
#   'Moldova',
#   '0101000020E6100000984C158C4A7A3D4043AD69DE716A4740',
#   0,
#   33,
#   'NaN'),
#  (635,
#   'Anenii Noi',
#   'Moldova',
#   '0101000020E6100000CE1951DA1B3C3D40386744696F704740',
#   0,
#   28,
#   'NaN'),
#  (636,
#   'Cahul',
#   'Moldova',
#   '0101000020E6100000A857CA32C4313C40EA04341136F44640',
#   63407,
#   50,
#   'NaN'),
#  (637,
#   'Chișinău',
#   'Moldova',
#   '0101000020E61000007AC7293A92DB3C40713D0AD7A3804740',
#   688134,
#   57,
#   'NaN'),
#  (638,
#   'Straşeni',
#   'Moldova',
#   '0101000020E61000007AC7293A929B3C40E0BE0E9C33924740',
#   0,
#   111,
#   'NaN'),
#  (639,
#   'Tiraspol',
#   'Moldova',
#   '0101000020E6100000A4703D0AD7A33D40DA1B7C61326D4740',
#   157000,
#   39,
#   'NaN'),
#  (640,
#   'Teleneşti',
#   'Moldova',
#   '0101000020E61000005AF5B9DA8A5D3C404703780B24C04740',
#   0,
#   65,
#   'NaN'),
#  (641,
#   'Taraclia',
#   'Moldova',
#   '0101000020E6100000EC2FBB270FAB3C40B30C71AC8BF34640',
#   0,
#   68,
#   'NaN'),
#  (642,
#   'Dubăsari',
#   'Moldova',
#   '0101000020E6100000613255302A293D40EFC9C342ADA14740',
#   23254,
#   31,
#   'NaN'),
#  (643,
#   'Cocieri',
#   'Moldova',
#   '0101000020E6100000234A7B832F1C3D403A234A7B83A74740',
#   0,
#   92,
#   'NaN'),
#  (644,
#   'Călăraşi',
#   'Moldova',
#   '0101000020E6100000C8073D9B554F3C40C66D3480B7A04740',
#   0,
#   127,
#   'NaN'),
#  (645,
#   'Glodeni',
#   'Moldova',
#   '0101000020E6100000F7E461A1D6843B4097900F7A36E34740',
#   0,
#   125,
#   'NaN'),
#  (646,
#   'Hînceşti',
#   'Moldova',
#   '0101000020E61000008104C58F31973C40FCA9F1D24D6A4740',
#   0,
#   128,
#   'NaN'),
#  (647,
#   'Nisporeni',
#   'Moldova',
#   '0101000020E6100000CE88D2DEE02B3C4043AD69DE718A4740',
#   0,
#   118,
#   'NaN'),
#  (648,
#   'Soroca',
#   'Moldova',
#   '0101000020E610000062A1D634EF483C40DC4603780B144840',
#   0,
#   197,
#   'NaN'),
#  (649,
#   'Ungheni',
#   'Moldova',
#   '0101000020E6100000B0726891EDCC3B4097FF907EFB9A4740',
#   0,
#   62,
#   'NaN'),
#  (650,
#   'Berane',
#   'Montenegro',
#   '0101000020E6100000C898BB9690DF3340A4703D0AD76B4540',
#   0,
#   675,
#   'NaN'),
#  (651,
#   'Plav',
#   'Montenegro',
#   '0101000020E6100000FC1873D712F23340BF7D1D38674C4540',
#   0,
#   947,
#   'NaN'),
#  (652,
#   'Andrijevica',
#   'Montenegro',
#   '0101000020E6100000D0B359F5B9CA33406744696FF05D4540',
#   0,
#   783,
#   'NaN'),
#  (653,
#   'Petnjica',
#   'Montenegro',
#   '0101000020E61000002D431CEBE2F63340CEAACFD556744540',
#   0,
#   724,
#   'NaN'),
#  (654,
#   'Gusinje',
#   'Montenegro',
#   '0101000020E610000068226C787AD53340ABCFD556EC474540',
#   0,
#   924,
#   'NaN'),
#  (655,
#   'Kolašin',
#   'Montenegro',
#   '0101000020E6100000F6285C8FC28533407DAEB6627F694540',
#   0,
#   954,
#   'NaN'),
#  (656,
#   'Podgorica',
#   'Montenegro',
#   '0101000020E6100000C0EC9E3C2C443340CFF753E3A53B4540',
#   145850,
#   36,
#   'NaN'),
#  (657,
#   'Bijelo Polje',
#   'Montenegro',
#   '0101000020E6100000C9E53FA4DFBE334088855AD3BC834540',
#   0,
#   576,
#   'NaN'),
#  (658,
#   'Bar',
#   'Montenegro',
#   '0101000020E6100000EFC9C342AD193340F9A067B3EA0B4540',
#   0,
#   5,
#   'NaN'),
#  (659,
#   'Budva',
#   'Montenegro',
#   '0101000020E6100000D7A3703D0AD7324086C954C1A8244540',
#   0,
#   7,
#   'NaN'),
#  (660,
#   'Cetinje',
#   'Montenegro',
#   '0101000020E61000005C8FC2F528EC3240E0BE0E9C33324540',
#   0,
#   651,
#   'NaN'),
#  (661,
#   'Danilovgrad',
#   'Montenegro',
#   '0101000020E6100000D044D8F0F41A3340832F4CA60A464540',
#   0,
#   50,
#   'NaN'),
#  (662,
#   'Herceg-Novi',
#   'Montenegro',
#   '0101000020E61000009A99999999893240A7E8482EFF394540',
#   0,
#   82,
#   'NaN'),
#  (663,
#   'Kotor',
#   'Montenegro',
#   '0101000020E61000004BC8073D9BC532408351499D80364540',
#   0,
#   13,
#   'NaN'),
#  (664,
#   'Mojkovac',
#   'Montenegro',
#   '0101000020E610000085EB51B81E953340A54E4013617B4540',
#   0,
#   847,
#   'NaN'),
#  (665,
#   'Nikšić',
#   'Montenegro',
#   '0101000020E6100000BEC1172653F532403333333333634540',
#   0,
#   639,
#   'NaN'),
#  (666,
#   'Plužine',
#   'Montenegro',
#   '0101000020E61000002D431CEBE2D63240166A4DF38E934540',
#   0,
#   704,
#   'NaN'),
#  (667,
#   'Pljevlja',
#   'Montenegro',
#   '0101000020E6100000423EE8D9AC5A33405BD3BCE314AD4540',
#   0,
#   798,
#   'NaN'),
#  (668,
#   'Rožaje',
#   'Montenegro',
#   '0101000020E6100000B3EA73B5152B3440158C4AEA046C4540',
#   0,
#   1007,
#   'NaN'),
#  (669,
#   'Šavnik',
#   'Montenegro',
#   '0101000020E6100000F085C954C11833407CF2B0506B7A4540',
#   0,
#   840,
#   'NaN'),
#  (670,
#   'Tivat',
#   'Montenegro',
#   '0101000020E6100000E0BE0E9C33B23240B9FC87F4DB374540',
#   0,
#   7,
#   'NaN'),
#  (671,
#   'Ulcinj',
#   'Montenegro',
#   '0101000020E6100000F7E461A1D63433403B70CE88D2F64440',
#   0,
#   35,
#   'NaN'),
#  (672,
#   'Žabljak',
#   'Montenegro',
#   '0101000020E6100000E561A1D6341F33407958A835CD934540',
#   0,
#   1449,
#   'NaN'),
#  (703,
#   'Vevčani',
#   'Macedonia',
#   '0101000020E610000080B74082E297344074B515FBCB9E4440',
#   0,
#   860,
#   'NaN'),
#  (704,
#   'Kočani',
#   'Macedonia',
#   '0101000020E6100000EFC9C342AD693640F7065F984CF54440',
#   0,
#   355,
#   'NaN'),
#  (705,
#   'Staro Nagoričane',
#   'Macedonia',
#   '0101000020E610000032772D211FD4354036AB3E575B194540',
#   0,
#   415,
#   'NaN'),
#  (706,
#   'Radoviš',
#   'Macedonia',
#   '0101000020E610000082734694F6763640B6847CD0B3D14440',
#   0,
#   382,
#   'NaN'),
#  (707,
#   'Sopište',
#   'Macedonia',
#   '0101000020E61000003D0AD7A3706D3540E0BE0E9C33FA4440',
#   0,
#   500,
#   'NaN'),
#  (708,
#   'Petrovec',
#   'Macedonia',
#   '0101000020E61000003D0AD7A3709D3540711B0DE02DF84440',
#   0,
#   224,
#   'NaN'),
#  (709,
#   'Bosilovo',
#   'Macedonia',
#   '0101000020E61000005F07CE1951BA36400E4FAF9465B84440',
#   0,
#   214,
#   'NaN'),
#  (710,
#   'Zrnovci',
#   'Macedonia',
#   '0101000020E6100000A857CA32C4713640211FF46C56ED4440',
#   0,
#   361,
#   'NaN'),
#  (711,
#   'Gradsko',
#   'Macedonia',
#   '0101000020E610000036AB3E575BF1354052B81E85EBC94440',
#   0,
#   157,
#   'NaN'),
#  (712,
#   'Lipkovo',
#   'Macedonia',
#   '0101000020E61000004B598638D6953540158C4AEA04144540',
#   0,
#   446,
#   'NaN'),
#  (713,
#   'Lozovo',
#   'Macedonia',
#   '0101000020E6100000F241CF66D5E73540CEAACFD556E44440',
#   0,
#   287,
#   'NaN'),
#  (714,
#   'Plasnica',
#   'Macedonia',
#   '0101000020E61000003A234A7B831F35407958A835CDBB4440',
#   0,
#   683,
#   'NaN'),
#  (715,
#   'Aračinovo',
#   'Macedonia',
#   '0101000020E6100000569FABADD88F3540A54E401361034540',
#   0,
#   263,
#   'NaN'),
#  (716,
#   'Studeničani',
#   'Macedonia',
#   '0101000020E6100000F241CF66D5873540A1D634EF38F54440',
#   0,
#   293,
#   'NaN'),
#  (717,
#   'Resen',
#   'Macedonia',
#   '0101000020E6100000C286A757CA02354033C4B12E6E8B4440',
#   0,
#   884,
#   'NaN'),
#  (718,
#   'Bogovinje',
#   'Macedonia',
#   '0101000020E610000027A089B0E1E93440F54A598638F64440',
#   0,
#   539,
#   'NaN'),
#  (719,
#   'Vinica',
#   'Macedonia',
#   '0101000020E61000008A1F63EE5A82364054742497FFF04440',
#   0,
#   405,
#   'NaN'),
#  (720,
#   'Belčišta',
#   'Macedonia',
#   '0101000020E61000006ADE718A8ED43440499D8026C2A64440',
#   0,
#   770,
#   'NaN'),
#  (721,
#   'Mogila',
#   'Macedonia',
#   '0101000020E6100000FE43FAEDEB60354012143FC6DC8D4440',
#   0,
#   588,
#   'NaN'),
#  (722,
#   'Veles',
#   'Macedonia',
#   '0101000020E610000011C7BAB88DC635404182E2C798DB4440',
#   0,
#   210,
#   'NaN'),
#  (723,
#   'Kavadarci',
#   'Macedonia',
#   '0101000020E610000089D2DEE00B033640E5F21FD26FB74440',
#   0,
#   275,
#   'NaN'),
#  (724,
#   'Kumanovo',
#   'Macedonia',
#   '0101000020E61000002D431CEBE2B63540FE43FAEDEB104540',
#   0,
#   345,
#   'NaN'),
#  (725,
#   'Ohrid',
#   'Macedonia',
#   '0101000020E610000093A9825149CD3440AC8BDB68008F4440',
#   0,
#   699,
#   'NaN'),
#  (726,
#   'Strumica',
#   'Macedonia',
#   '0101000020E61000004D840D4FAFA436400000000000B84440',
#   0,
#   227,
#   'NaN'),
#  (727,
#   'Makedonski Brod',
#   'Macedonia',
#   '0101000020E61000002CD49AE61D373540E09C11A5BDC14440',
#   0,
#   551,
#   'NaN'),
#  (728,
#   'Rostuša',
#   'Macedonia',
#   '0101000020E61000009A99999999993440AE47E17A14CE4440',
#   0,
#   789,
#   'NaN'),
#  (729,
#   'Struga',
#   'Macedonia',
#   '0101000020E6100000933A014D84AD3440115839B4C8964440',
#   0,
#   696,
#   'NaN'),
#  (730,
#   'Čučer-Sandevo',
#   'Macedonia',
#   '0101000020E6100000A60A462575623540931804560E0D4540',
#   0,
#   488,
#   'NaN'),
#  (731,
#   'Novo Selo',
#   'Macedonia',
#   '0101000020E61000005227A089B0E13640228E75711BB54440',
#   0,
#   239,
#   'NaN'),
#  (732,
#   'Zelenikovo',
#   'Macedonia',
#   '0101000020E61000002DB29DEFA7963540613255302AF14440',
#   0,
#   222,
#   'NaN'),
#  (733,
#   'Star Dojran',
#   'Macedonia',
#   '0101000020E61000000E4FAF9465B836401D5A643BDF974440',
#   0,
#   169,
#   'NaN'),
#  (734,
#   'Skopje',
#   'Macedonia',
#   '0101000020E6100000E5D022DBF96E35400000000000004540',
#   494087,
#   268,
#   'NaN'),
#  (735,
#   'Štip',
#   'Macedonia',
#   '0101000020E6100000DFE00B93A932364010E9B7AF03DF4440',
#   0,
#   309,
#   'NaN'),
#  (736,
#   'Makedonska Kamenica',
#   'Macedonia',
#   '0101000020E61000002D211FF46C963640DFE00B93A9024540',
#   0,
#   529,
#   'NaN'),
#  (737,
#   'Ilinden',
#   'Macedonia',
#   '0101000020E610000014AE47E17A9435409EEFA7C64BFF4440',
#   0,
#   227,
#   'NaN'),
#  (738,
#   'Demir Hisar',
#   'Macedonia',
#   '0101000020E61000008816D9CEF733354040355EBA499C4440',
#   0,
#   644,
#   'NaN'),
#  (739,
#   'Želino',
#   'Macedonia',
#   '0101000020E610000039454772F90F3540F6285C8FC2FD4440',
#   0,
#   421,
#   'NaN'),
#  (740,
#   'Prilep',
#   'Macedonia',
#   '0101000020E6100000AE47E17A148E3540C0EC9E3C2CAC4440',
#   0,
#   651,
#   'NaN'),
#  (741,
#   'Bitola',
#   'Macedonia',
#   '0101000020E6100000F4FDD478E956354005A3923A01854440',
#   86528,
#   624,
#   'NaN'),
#  (742,
#   'Krivogaštani',
#   'Macedonia',
#   '0101000020E6100000A2B437F8C2543540DE02098A1FAB4440',
#   0,
#   609,
#   'NaN'),
#  (743,
#   'Kruševo',
#   'Macedonia',
#   '0101000020E6100000C898BB96903F35403A92CB7F48AF4440',
#   0,
#   1215,
#   'NaN'),
#  (744,
#   'Vasilevo',
#   'Macedonia',
#   '0101000020E6100000F853E3A59BA436404D840D4FAFBC4440',
#   0,
#   233,
#   'NaN'),
#  (745,
#   'Gostivar',
#   'Macedonia',
#   '0101000020E61000002A3A92CB7FE83440DACEF753E3E54440',
#   0,
#   535,
#   'NaN'),
#  (746,
#   'Vrapčište',
#   'Macedonia',
#   '0101000020E61000006D567DAEB6E2344026E4839ECDEA4440',
#   0,
#   572,
#   'NaN'),
#  (747,
#   'Novaci',
#   'Macedonia',
#   '0101000020E6100000DAACFA5C6D7535404C37894160854440',
#   0,
#   580,
#   'NaN'),
#  (748,
#   'Čaška',
#   'Macedonia',
#   '0101000020E61000008C4AEA0434B135402575029A08D34440',
#   0,
#   261,
#   'NaN'),
#  (749,
#   'Kratovo',
#   'Macedonia',
#   '0101000020E61000002063EE5A422E3640D200DE02090A4540',
#   0,
#   619,
#   'NaN'),
#  (750,
#   'Probištip',
#   'Macedonia',
#   '0101000020E6100000B1BFEC9E3C2C364063EE5A423E004540',
#   0,
#   544,
#   'NaN'),
#  (751,
#   'Debar',
#   'Macedonia',
#   '0101000020E61000002E90A0F831863440DE02098A1FC34440',
#   0,
#   655,
#   'NaN'),
#  (752,
#   'Centar Župa',
#   'Macedonia',
#   '0101000020E6100000AC8BDB68008F344093A9825149BD4440',
#   0,
#   739,
#   'NaN'),
#  (753,
#   'Rosoman',
#   'Macedonia',
#   '0101000020E61000008A8EE4F21FF23540EEEBC03923C24440',
#   0,
#   142,
#   'NaN'),
#  (754,
#   'Jegunovce',
#   'Macedonia',
#   '0101000020E6100000E4839ECDAA1F35407E1D386744094540',
#   0,
#   389,
#   'NaN'),
#  (755,
#   'Demir Kapija',
#   'Macedonia',
#   '0101000020E61000003B014D840D3F3640EB73B515FBB34440',
#   0,
#   105,
#   'NaN'),
#  (756,
#   'Negotino',
#   'Macedonia',
#   '0101000020E61000008104C58F3117364020D26F5F07BE4440',
#   0,
#   144,
#   'NaN'),
#  (757,
#   'Konče',
#   'Macedonia',
#   '0101000020E6100000E0BE0E9C33623640F31FD26F5FBF4440',
#   0,
#   578,
#   'NaN'),
#  (758,
#   'Dolneni',
#   'Macedonia',
#   '0101000020E61000004E621058397435408351499D80B64440',
#   0,
#   620,
#   'NaN'),
#  (759,
#   'Sveti Nikole',
#   'Macedonia',
#   '0101000020E6100000FE43FAEDEBF03540BBB88D06F0EE4440',
#   0,
#   307,
#   'NaN'),
#  (760,
#   'Valandovo',
#   'Macedonia',
#   '0101000020E61000008FC2F5285C8F36400DE02D90A0A84440',
#   0,
#   126,
#   'NaN'),
#  (761,
#   'Kičevo',
#   'Macedonia',
#   '0101000020E610000068226C787AF5344061545227A0C14440',
#   0,
#   616,
#   'NaN'),
#  (762,
#   'Delčevo',
#   'Macedonia',
#   '0101000020E610000082E2C798BBC636407AC7293A92FB4440',
#   0,
#   598,
#   'NaN'),
#  (763,
#   'Tetovo',
#   'Macedonia',
# ...
#   'Vyborg',
#   'Russia',
#   '0101000020E61000001AC05B2041C13C40C3D32B65195A4E40',
#   117201,
#   21,
#   'NaN'),
#  (2243,
#   'Svetogorsk',
#   'Russia',
#   '0101000020E6100000098A1F63EEEA3C40DB8AFD65F78C4E40',
#   30115,
#   46,
#   'NaN'),
#  (2245,
#   'Mezen',
#   'Russia',
#   '0101000020E61000001F85EB51B81E4640AD69DE718A765040',
#   3672,
#   13,
#   'NaN'),
#  (2246,
#   'Buzuluk',
#   'Russia',
#   '0101000020E6100000E10B93A982214A40CE1951DA1B644A40',
#   87714,
#   73,
#   'NaN'),
#  (2249,
#   'Saransk',
#   'Russia',
#   '0101000020E6100000D7A3703D0A974640849ECDAACF154B40',
#   303394,
#   150,
#   'NaN'),
#  (2252,
#   'Alatyr',
#   'Russia',
#   '0101000020E6100000CDCCCCCCCC4C47405B423EE8D96C4B40',
#   46427,
#   133,
#   'NaN'),
#  (2265,
#   'Ryazan',
#   'Russia',
#   '0101000020E61000005C8FC2F528DC43408FC2F5285C4F4B40',
#   520173,
#   127,
#   'NaN'),
#  (2266,
#   'Bezhetsk',
#   'Russia',
#   '0101000020E6100000B81E85EB5158424027A089B0E1E14C40',
#   34736,
#   127,
#   'NaN'),
#  (2267,
#   'Novomoskovsk',
#   'Russia',
#   '0101000020E61000005C8FC2F5281C4340EC51B81E850B4B40',
#   130982,
#   218,
#   'NaN'),
#  (2268,
#   'Zheleznogorsk',
#   'Russia',
#   '0101000020E61000004F401361C3B34140764F1E166A2D4A40',
#   97900,
#   218,
#   'NaN'),
#  (2270,
#   'Starsy Oskol',
#   'Russia',
#   '0101000020E6100000EC51B81E85EB4240F5DBD78173A64940',
#   226977,
#   134,
#   'NaN'),
#  (2271,
#   'Rostov',
#   'Russia',
#   '0101000020E6100000EBE2361AC0B343409C33A2B437984C40',
#   33803,
#   102,
#   'NaN'),
#  (2272,
#   'Gubkin',
#   'Russia',
#   '0101000020E610000029ED0DBE30B142407AA52C431CA34940',
#   272,
#   174,
#   'NaN'),
#  (2276,
#   'Noginsk',
#   'Russia',
#   '0101000020E61000003D0AD7A3703D43401D38674469EF4B40',
#   229731,
#   124,
#   'NaN'),
#  (2277,
#   'Staraya Russa',
#   'Russia',
#   '0101000020E6100000D0B359F5B95A3F40C8073D9B55FF4C40',
#   34303,
#   23,
#   'NaN'),
#  (2278,
#   'Tikhvin',
#   'Russia',
#   '0101000020E6100000FD87F4DBD7C14040FB3A70CE88D24D40',
#   62075,
#   50,
#   'NaN'),
#  (2280,
#   'Yoshkar Ola',
#   'Russia',
#   '0101000020E61000009CA223B9FCEF47406FF085C954514C40',
#   324406,
#   103,
#   'NaN'),
#  (2285,
#   'Bologoye',
#   'Russia',
#   '0101000020E610000066F7E461A10641401DC9E53FA4EF4C40',
#   25142,
#   176,
#   'NaN'),
#  (2286,
#   'Mikhaylovka',
#   'Russia',
#   '0101000020E6100000A4703D0AD79B4540FFB27BF2B0084940',
#   58898,
#   79,
#   'NaN'),
#  (2287,
#   'Novozybkov',
#   'Russia',
#   '0101000020E61000008BFD65F7E4F13F404DF38E5374444A40',
#   43534,
#   162,
#   'NaN'),
#  (2288,
#   'Chapayevsk',
#   'Russia',
#   '0101000020E6100000143FC6DCB5DC4840143FC6DCB57C4A40',
#   107164,
#   52,
#   'NaN'),
#  (2289,
#   'Novokuybishevsk',
#   'Russia',
#   '0101000020E610000092CB7F48BFF548408FC2F5285C8F4A40',
#   152334,
#   63,
#   'NaN'),
#  (2291,
#   'Michurinsk',
#   'Russia',
#   '0101000020E610000000000000004044403333333333734A40',
#   93499,
#   145,
#   'NaN'),
#  (2293,
#   'Alekseyevka',
#   'Russia',
#   '0101000020E6100000C66D3480B7584340CFF753E3A5534940',
#   39848,
#   114,
#   'NaN'),
#  (2294,
#   'Valuyki',
#   'Russia',
#   '0101000020E6100000BF0E9C33A20C4340FBCBEEC9C31A4940',
#   35887,
#   103,
#   'NaN'),
#  (2296,
#   'Lgov',
#   'Russia',
#   '0101000020E6100000DE02098A1FA3414062A1D634EFD84940',
#   23500,
#   178,
#   'NaN'),
#  (2297,
#   'Rybinsk',
#   'Russia',
#   '0101000020E6100000295C8FC2F5684340917EFB3A70064D40',
#   216724,
#   101,
#   'NaN'),
#  (2298,
#   'Uglich',
#   'Russia',
#   '0101000020E61000000AD7A3703D2A4340DE02098A1FC34C40',
#   37732,
#   112,
#   'NaN'),
#  (2299,
#   'Slantsy',
#   'Russia',
#   '0101000020E6100000DE02098A1F133C40E71DA7E8488E4D40',
#   36209,
#   44,
#   'NaN'),
#  (2300,
#   'Vyska',
#   'Russia',
#   '0101000020E610000030BB270F0B1545406F8104C58FA94B40',
#   61664,
#   108,
#   'NaN'),
#  (2301,
#   'Armavir',
#   'Russia',
#   '0101000020E6100000713D0AD7A39044408E75711B0D804640',
#   199548,
#   183,
#   'NaN'),
#  (2302,
#   'Stavropol',
#   'Russia',
#   '0101000020E61000003D0AD7A370FD44406666666666864640',
#   363064,
#   551,
#   'NaN'),
#  (2303,
#   'Bryansk',
#   'Russia',
#   '0101000020E6100000D7A3703D0A374140E17A14AE47A14A40',
#   427236,
#   153,
#   'NaN'),
#  (2304,
#   'Kropotkin',
#   'Russia',
#   '0101000020E61000003480B740824A44405305A3923AB94640',
#   79599,
#   117,
#   'NaN'),
#  (2305,
#   'Shchekino',
#   'Russia',
#   '0101000020E6100000992A1895D4C14240992A1895D4014B40',
#   86088,
#   243,
#   'NaN'),
#  (2306,
#   'Derbent',
#   'Russia',
#   '0101000020E610000088F4DBD781234840BADA8AFD65074540',
#   105965,
#   83,
#   'NaN'),
#  (2307,
#   'Nikolayevsk',
#   'Russia',
#   '0101000020E6100000AD69DE718AB6464099BB96900F024940',
#   16044,
#   8,
#   'NaN'),
#  (2308,
#   'Tula',
#   'Russia',
#   '0101000020E61000000DE02D90A0D042409A99999999194B40',
#   489486,
#   155,
#   'NaN'),
#  (2309,
#   'Murom',
#   'Russia',
#   '0101000020E610000085EB51B81E054540B7D100DE02C94B40',
#   131287,
#   116,
#   'NaN'),
#  (2311,
#   'Kamyshin',
#   'Russia',
#   '0101000020E61000003333333333B34640984C158C4A0A4940',
#   128626,
#   41,
#   'NaN'),
#  (2312,
#   'Syzran',
#   'Russia',
#   '0101000020E61000003D0AD7A3703D4840F6285C8FC2954A40',
#   189338,
#   64,
#   'NaN'),
#  (2313,
#   'Kuznetsk',
#   'Russia',
#   '0101000020E6100000CDCCCCCCCC4C47401D386744698F4A40',
#   95574,
#   232,
#   'NaN'),
#  (2314,
#   'Gelendzhik',
#   'Russia',
#   '0101000020E610000063EE5A423E084340D3DEE00B93494640',
#   55508,
#   0,
#   'NaN'),
#  (2315,
#   'Sharya',
#   'Russia',
#   '0101000020E61000008C4AEA0434C14640AA8251499D304D40',
#   35532,
#   121,
#   'NaN'),
#  (2316,
#   'Murmansk',
#   'Russia',
#   '0101000020E6100000CDCCCCCCCC8C4040AE47E17A143E5140',
#   319263,
#   76,
#   'NaN'),
#  (2318,
#   'Frolovo',
#   'Russia',
#   '0101000020E610000033C4B12E6ED3454050FC1873D7E24840',
#   40882,
#   110,
#   'NaN'),
#  (2319,
#   'Severomorsk',
#   'Russia',
#   '0101000020E610000003780B2428B640409B559FABAD445140',
#   53921,
#   24,
#   'NaN'),
#  (2320,
#   'Dzerzhinsk',
#   'Russia',
#   '0101000020E61000007B14AE47E1BA45408E75711B0D204C40',
#   256537,
#   96,
#   'NaN'),
#  (2322,
#   'Uryupinsk',
#   'Russia',
#   '0101000020E61000000E4FAF9465004540FB5C6DC5FE624940',
#   41644,
#   71,
#   'NaN'),
#  (2328,
#   'Nevinnomyssk',
#   'Russia',
#   '0101000020E61000009A99999999F94440F31FD26F5F4F4640',
#   134380,
#   337,
#   'NaN'),
#  (2329,
#   'Velikiye Luki',
#   'Russia',
#   '0101000020E610000085EB51B81E853E40295C8FC2F5284C40',
#   103149,
#   103,
#   'NaN'),
#  (2330,
#   'Nizhnekamsk',
#   'Russia',
#   '0101000020E6100000295C8FC2F5E84940E02D90A0F8D14B40',
#   234297,
#   130,
#   'NaN'),
#  (2331,
#   'Kirov',
#   'Russia',
#   '0101000020E610000010E9B7AF0327414042CF66D5E70A4B40',
#   39319,
#   183,
#   'NaN'),
#  (2332,
#   'Dyatkovo',
#   'Russia',
#   '0101000020E6100000CF66D5E76A2B41406C09F9A067CB4A40',
#   33527,
#   209,
#   'NaN'),
#  (2334,
#   'Borisoglebsk',
#   'Russia',
#   '0101000020E6100000DE9387855A0B45408104C58F31AF4940',
#   68597,
#   106,
#   'NaN'),
#  (2335,
#   'Klintsy',
#   'Russia',
#   '0101000020E6100000C8073D9B551F40401973D712F2614A40',
#   66336,
#   166,
#   'NaN'),
#  (2336,
#   'Mozhga',
#   'Russia',
#   '0101000020E61000008F53742497174A40431CEBE2363A4C40',
#   47270,
#   136,
#   'NaN'),
#  (2337,
#   'Rzhev',
#   'Russia',
#   '0101000020E610000052B81E85EB294140C5FEB27BF2204C40',
#   63414,
#   183,
#   'NaN'),
#  (2339,
#   'Vichuga',
#   'Russia',
#   '0101000020E6100000C9E53FA4DFF64440DC4603780B9C4C40',
#   39071,
#   139,
#   'NaN'),
#  (2340,
#   'Mtsensk',
#   'Russia',
#   '0101000020E6100000832F4CA60A46424027A089B0E1A14A40',
#   47609,
#   183,
#   'NaN'),
#  (2341,
#   'Kanash',
#   'Russia',
#   '0101000020E61000004ED1915CFEBB4740613255302AC14B40',
#   49886,
#   187,
#   'NaN'),
#  (2343,
#   'Shuya',
#   'Russia',
#   '0101000020E610000066F7E461A1AE4440857CD0B3596D4C40',
#   60705,
#   87,
#   'NaN'),
#  (2344,
#   'Torzhok',
#   'Russia',
#   '0101000020E6100000304CA60A467D414024287E8CB9834C40',
#   48546,
#   152,
#   'NaN'),
#  (2346,
#   'Otradnyy',
#   'Russia',
#   '0101000020E6100000B1506B9A77AC4940E3361AC05BB04A40',
#   50127,
#   58,
#   'NaN'),
#  (2347,
#   'Serpukhov',
#   'Russia',
#   '0101000020E6100000D7A3703D0AB742406519E25817774B40',
#   135584,
#   167,
#   'NaN'),
#  (2348,
#   'Balakovo',
#   'Russia',
#   '0101000020E61000006666666666E64740A4703D0AD7034A40',
#   199572,
#   25,
#   'NaN'),
#  (2349,
#   'Atkarsk',
#   'Russia',
#   '0101000020E6100000D6C56D34807F4640D578E92631F04940',
#   27554,
#   182,
#   'NaN'),
#  (2350,
#   'Kirovo-Chepetsk',
#   'Russia',
#   '0101000020E6100000A1F831E6AE05494082734694F6464D40',
#   90252,
#   139,
#   'NaN'),
#  (2351,
#   'Kirov',
#   'Russia',
#   '0101000020E6100000F6285C8FC2D548404FAF9465884B4D40',
#   457437,
#   147,
#   'NaN'),
#  (2352,
#   'Serdobsk',
#   'Russia',
#   '0101000020E61000005C2041F1631C4640091B9E5E293B4A40',
#   36652,
#   194,
#   'NaN'),
#  (2353,
#   'Aleksin',
#   'Russia',
#   '0101000020E6100000075F984C158C4240992A1895D4414B40',
#   66885,
#   184,
#   'NaN'),
#  (2354,
#   'Shumerlya',
#   'Russia',
#   '0101000020E610000011363CBD52364740E78C28ED0DBE4B40',
#   35230,
#   83,
#   'NaN'),
#  (2355,
#   'Yefremov',
#   'Russia',
#   '0101000020E6100000643BDF4F8D0F4340B3EA73B515934A40',
#   45497,
#   176,
#   'NaN'),
#  (2356,
#   'Buynaksk',
#   'Russia',
#   '0101000020E61000005839B4C8768E4740A69BC420B06A4540',
#   75800,
#   428,
#   'NaN'),
#  (2357,
#   'Makhachkala',
#   'Russia',
#   '0101000020E61000000000000000C047403D0AD7A3707D4540',
#   554981,
#   6,
#   'NaN'),
#  (2358,
#   'Yaroslavl',
#   'Russia',
#   '0101000020E61000008FC2F5285CEF43408FC2F5285CCF4C40',
#   606730,
#   94,
#   'NaN'),
#  (2359,
#   'Sovetsk',
#   'Russia',
#   '0101000020E610000018265305A37A4840355EBA490CCA4C40',
#   17869,
#   120,
#   'NaN'),
#  (2362,
#   'Bogoroditsk',
#   'Russia',
#   '0101000020E6100000CA54C1A8A40E4340091B9E5E29E34A40',
#   39553,
#   236,
#   'NaN'),
#  (2363,
#   'Morshansk',
#   'Russia',
#   '0101000020E610000082734694F6E64440E0BE0E9C33BA4A40',
#   49350,
#   115,
#   'NaN'),
#  (2364,
#   'Obninsk',
#   'Russia',
#   '0101000020E61000008FC2F5285C4F4240984C158C4A8A4B40',
#   107392,
#   169,
#   'NaN'),
#  (2365,
#   'Georgievsk',
#   'Russia',
#   '0101000020E6100000F931E6AE25BC4540B1506B9A77144640',
#   72649,
#   302,
#   'NaN'),
#  (2367,
#   'Vladimir',
#   'Russia',
#   '0101000020E6100000B1506B9A77344440713D0AD7A3104C40',
#   318648,
#   153,
#   'NaN'),
#  (2369,
#   'Ulyanovsk',
#   'Russia',
#   '0101000020E610000014AE47E17A3448400AD7A3703D2A4B40',
#   640680,
#   149,
#   'NaN'),
#  (2370,
#   'Kirsanov',
#   'Russia',
#   '0101000020E6100000401361C3D35B4540F931E6AE25544A40',
#   17975,
#   164,
#   'NaN'),
#  (2371,
#   'Kotovsk',
#   'Russia',
#   '0101000020E61000001B0DE02D90C0444032772D211F4C4A40',
#   33077,
#   128,
#   'NaN'),
#  (2372,
#   'Tambov',
#   'Russia',
#   '0101000020E6100000D7A3703D0AB744403D0AD7A3705D4A40',
#   301482,
#   135,
#   'NaN'),
#  (2373,
#   'Volkhov',
#   'Russia',
#   '0101000020E6100000DE9387855A2B4040575BB1BFECF64D40',
#   45673,
#   35,
#   'NaN'),
#  (2374,
#   'Vyshnniy Volochek',
#   'Russia',
#   '0101000020E610000055302AA913484140B4C876BE9FCA4C40',
#   53800,
#   160,
#   'NaN'),
#  (2375,
#   'Orel',
#   'Russia',
#   '0101000020E6100000295C8FC2F50842405C8FC2F5287C4A40',
#   334552,
#   144,
#   'NaN'),
#  (2376,
#   'Kandalaksha',
#   'Russia',
#   '0101000020E610000030BB270F0B354040E6AE25E483CA5040',
#   106798,
#   42,
#   'NaN'),
#  (2378,
#   'Petrozavodsk',
#   'Russia',
#   '0101000020E6100000A4703D0AD7234140CDCCCCCCCCEC4E40',
#   265025,
#   39,
#   'NaN'),
#  (2380,
#   'Omutninsk',
#   'Russia',
#   '0101000020E6100000F8C264AA60144A40CEAACFD556544D40',
#   32800,
#   186,
#   'NaN'),
#  (2383,
#   'Kirs',
#   'Russia',
#   '0101000020E6100000567DAEB6621F4A400EBE30992AA84D40',
#   11385,
#   162,
#   'NaN'),
#  (2384,
#   'Kondopoga',
#   'Russia',
#   '0101000020E6100000772D211FF42441406D567DAEB61A4F40',
#   34360,
#   62,
#   'NaN'),
#  (2385,
#   'Ruzayevka',
#   'Russia',
#   '0101000020E610000011363CBD5276464000917EFB3A084B40',
#   49311,
#   152,
#   'NaN'),
#  (2386,
#   'Tver',
#   'Russia',
#   '0101000020E610000052B81E85EBF14140AE47E17A146E4C40',
#   400212,
#   132,
#   'NaN'),
#  (2387,
#   'Kotelnich',
#   'Russia',
#   '0101000020E6100000AA60545227284840575BB1BFEC264D40',
#   28431,
#   134,
#   'NaN'),
#  (2388,
#   'Kaliningrad',
#   'Russia',
#   '0101000020E6100000014D840D4F7F34409A99999999594B40',
#   434954,
#   2,
#   'NaN'),
#  (2390,
#   'Penza',
#   'Russia',
#   '0101000020E61000000000000000804640D7A3703D0A974A40',
#   512602,
#   218,
#   'NaN'),
#  (2391,
#   'Velikiy Ustyug',
#   'Russia',
#   '0101000020E610000058A835CD3B264740B537F8C264624E40',
#   33237,
#   59,
#   'NaN'),
#  (2393,
#   'Balakhna',
#   'Russia',
#   '0101000020E6100000075F984C15CC4540D734EF38453F4C40',
#   63083,
#   74,
#   'NaN'),
#  (2394,
#   'Podolsk',
#   'Russia',
#   '0101000020E6100000401361C3D3C34240FFB27BF2B0B04B40',
#   320635,
#   167,
#   'NaN'),
#  (2395,
#   'Kineshma',
#   'Russia',
#   '0101000020E6100000713D0AD7A31045405C8FC2F528BC4C40',
#   92983,
#   80,
#   'NaN'),
#  (2396,
#   'Yegoryevsk',
#   'Russia',
#   '0101000020E61000004F401361C38343401AC05B2041B14B40',
#   89795,
#   145,
#   'NaN'),
#  (2397,
#   'Volzhskiy',
#   'Russia',
#   '0101000020E6100000DE02098A1F6346402F6EA301BC654840',
#   323293,
#   21,
#   'NaN'),
#  (2398,
#   'Volgograd',
#   'Russia',
#   '0101000020E610000000000000004046407B14AE47E15A4840',
#   984000,
#   36,
#   'NaN'),
#  (2399,
#   'Onega',
#   'Russia',
#   '0101000020E6100000C442AD69DE094340910F7A36ABF64F40',
#   22693,
#   8,
#   'NaN'),
#  (2401,
#   'Apatity',
#   'Russia',
#   '0101000020E6100000FCA9F1D24DB240409B559FABADE45040',
#   66907,
#   165,
#   'NaN'),
#  (2402,
#   'Umba',
#   'Russia',
#   '0101000020E61000004E621058392C4140A4DFBE0E9CAB5040',
#   6128,
#   28,
#   'NaN'),
#  (2403,
#   'Kovda',
#   'Russia',
#   '0101000020E6100000567DAEB6626F4040711B0DE02DAC5040',
#   20,
#   19,
#   'NaN'),
#  (2404,
#   'Kirovsk',
#   'Russia',
#   '0101000020E6100000E86A2BF697D5404097FF907EFBE65040',
#   29605,
#   371,
#   'NaN'),
#  (2406,
#   'Belgorod',
#   'Russia',
#   '0101000020E6100000696FF085C94C4240713D0AD7A3504940',
#   345289,
#   197,
#   'NaN'),
#  (2407,
#   'Taganrog',
#   'Russia',
#   '0101000020E6100000F6285C8FC27543403D0AD7A3709D4740',
#   279056,
#   12,
#   'NaN'),
#  (2408,
#   'Velsk',
#   'Russia',
#   '0101000020E6100000B1506B9A770C45400DE02D90A0884E40',
#   26300,
#   87,
#   'NaN'),
#  (2409,
#   'Sasovo',
#   'Russia',
#   '0101000020E610000007F0164850F444404D840D4FAF2C4B40',
#   31325,
#   115,
#   'NaN'),
#  (2410,
#   'Voronezh',
#   'Russia',
#   '0101000020E6100000C3F5285C8FA243403D0AD7A370DD4940',
#   844000,
#   101,
#   'NaN'),
#  (2411,
#   'Syktyvkar',
#   'Russia',
#   '0101000020E6100000295C8FC2F568494014AE47E17AD44E40',
#   230910,
#   123,
#   'NaN'),
#  (2413,
#   'Lipetsk',
#   'Russia',
#   '0101000020E610000052B81E85EBD143408FC2F5285C4F4A40',
#   515655,
#   107,
#   'NaN'),
#  (2414,
#   'Yelets',
#   'Russia',
#   '0101000020E610000000000000004043400AD7A3703D4A4A40',
#   115919,
#   120,
#   'NaN'),
#  (2417,
#   'Gryazi',
#   'Russia',
#   '0101000020E61000008F53742497F74340C8073D9B553F4A40',
#   47413,
#   126,
#   'NaN'),
#  (2418,
#   'Kazan',
#   'Russia',
#   '0101000020E61000000EBE30992A9048409CA223B9FCDF4B40',
#   1115000,
#   55,
#   'NaN'),
#  (2419,
#   'Arzamas',
#   'Russia',
#   '0101000020E61000006666666666E645403333333333B34B40',
#   142597,
#   128,
#   'NaN'),
#  (2420,
#   'Buy',
#   'Russia',
#   '0101000020E6100000DE02098A1FC34440832F4CA60A3E4D40',
#   26486,
#   95,
#   'NaN'),
#  (2421,
#   'Kostroma',
#   'Russia',
#   '0101000020E6100000B81E85EB51784440C3F5285C8FE24C40',
#   277656,
#   110,
#   'NaN'),
#  (2422,
#   'Zelenodolsk',
#   'Russia',
#   '0101000020E6100000A4703D0AD75348404182E2C798EB4B40',
#   99600,
#   57,
#   'NaN'),
#  (2424,
#   'Chistopol',
#   'Russia',
#   '0101000020E61000000B4625750252494058CA32C4B1AE4B40',
#   62200,
#   102,
#   'NaN'),
#  (2427,
#   'Kem',
#   'Russia',
#   '0101000020E6100000F085C954C1484140CC5D4BC8073D5040',
#   13829,
#   16,
#   'NaN'),
#  (2428,
#   'Belomorsk',
#   'Russia',
#   '0101000020E61000006EA301BC05624140FDF675E09C215040',
#   12165,
#   0,
#   'NaN'),
#  (2431,
#   'Cherkessk',
#   'Russia',
#   '0101000020E610000048E17A14AE0745401361C3D32B254640',
#   116224,
#   474,
#   'NaN'),
#  (2432,
#   'Livny',
#   'Russia',
#   '0101000020E6100000E8D9ACFA5CCD42409FABADD85F364A40',
#   52915,
#   180,
#   'NaN'),
#  (2434,
#   'Kursk',
#   'Russia',
#   '0101000020E6100000B81E85EB511842401F85EB51B8DE4940',
#   409431,
#   232,
#   'NaN'),
#  (2440,
#   'Archangel',
#   'Russia',
#   '0101000020E6100000F6285C8FC2454440CDCCCCCCCC245040',
#   356051,
#   1,
#   'NaN'),
#  (2443,
#   'Nikel',
#   'Russia',
#   '0101000020E6100000645DDC4603383E401895D409685A5140',
#   15866,
#   68,
#   'NaN'),
#  (2446,
#   'Sochi',
#   'Russia',
#   '0101000020E61000003D0AD7A370DD4340EC51B81E85CB4540',
#   327608,
#   44,
#   'NaN'),
#  (2447,
#   'Novoshakhtinsk',
#   'Russia',
#   '0101000020E6100000F6285C8FC2F54340C3F5285C8FE24740',
#   99478,
#   160,
#   'NaN'),
#  (2448,
#   'Bugrino',
#   'Russia',
#   '0101000020E6100000BBB88D06F0A648400F9C33A2B4335140',
#   300,
#   12,
#   'NaN'),
#  (2449,
#   'Shakhty',
#   'Russia',
#   '0101000020E6100000C3F5285C8F224440EA04341136DC4740',
#   221312,
#   101,
#   'NaN'),
#  (2450,
#   'Bataysk',
#   'Russia',
#   '0101000020E61000002C6519E258DF4340E10B93A982914740',
#   109962,
#   10,
#   'NaN'),
#  ...]
